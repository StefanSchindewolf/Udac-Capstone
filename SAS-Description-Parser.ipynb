# %% [markdown]
# # SAS File Description Parser

# %% [markdown]
# **Usage:**
# - Run this cell in Notebook located in the same folder as the SAS definition file
# - Define the file name in the first cell
# - Run all 3 cells
# - The result is displayed at the end

# %%
# Modules and Filename config
import pandas as pd
import logging
import sys
import json

file_name = 'I94_SAS_Labels_Descriptions.SAS'

# %%
# Small and unreliable SAS config parser
logging.basicConfig(
    level=logging.WARNING,
    format='%(asctime)s %(levelname)s \t %(message)s ',
    datefmt='%Y-%m-%d %H:%M:%S',
    stream=sys.stdout,
)
log = logging.getLogger('log')

def get_sas_definitions(file):
    """ Checks a given .SAS file line by line searching for text patterns.
        Idenfified variables are collected in a dictionary.
        Value constraints are stored as <variable label>+'l'
        
        Returns:  dict with variables, variable discriptions 
                  and value constraints
    
    """
    # Empty dict to return
    data_dict = dict()
    # Flag if we found a single line variable description
    confline = False
    # Flag if we found a multiple line variable description
    multiline = False
    # Placeholder for variable name
    varname = ''
    
    with open(file,mode='r') as f:
        for line in f.read().splitlines():
            line = line.strip()
            # Recognize data variable descriptions by "/*" at the start of the line
            
            # If we have the separator at beginning and end then we can store a variable
            if ((line.startswith('/* ')) and (line.endswith(' */'))):
                multiline = False
                line = line.lstrip('/* ').rstrip(' */')
                splitted = line.split(sep='-')
                colnames = splitted[0].strip().lower()
                desc = splitted[1].strip()
                if '&' in colnames:
                    colnames = colnames.split(sep='&')
                    for cn in colnames:
                        cn = cn.strip()
                        data_dict[cn] = desc
                        log.info('Found Field Description for column {}: {}'.format(cn, desc))
                else:
                    data_dict[colnames] = desc
                    log.info('Found Field Description for column {}: {}'.format(colnames, desc))
            
            # If its just the start of a multiline description then store the first part
            # of the description and set the multiline flag
            elif line.startswith('/* '):
                multiline = True
                line = line.lstrip('/* ').rstrip()
                try:
                    splitted = line.split(sep='-', maxsplit=1)
                    colnames = splitted[0].strip().lower()
                    desc = splitted[1].strip()
                except:
                    splitted = line.split(sep=' ', maxsplit=1)
                    colnames = splitted[0].strip().lower()
                    desc = splitted[1].strip()
                if '&' in colnames:
                    colnames = colnames.split(sep='&')
                    for cn in colnames:
                        cn = cn.strip()
                        data_dict[cn.lower()] = desc
                        log.info('Found Field Description for column {}: {}'.format(cn, desc))
                else:
                    data_dict[colnames] = desc
                    log.info('Found Field Description for column {}: {}'.format(colnames, desc))
            else:
                # If a multiline description was started then just append the line
                if (multiline == True and line.endswith(' */') == True):
                    multiline = False
                    line = line.lstrip('/* ').rstrip()
                    if '&' in colnames:
                        colnames = colnames.split(sep='&').lower()
                        for cn in colnames:
                            cn = cn.strip()
                            data_dict[cn] = data_dict[cn] + line
                            log.info('Appending Field Description for column {}'.format(cn))
                    else:
                        data_dict[colnames] = data_dict[colnames] + desc
                        log.info('Appending Field Description for column {}'.format(colnames))
                # Except its the end of the multiline description
                elif (multiline == True and line.endswith(' */') == False):
                    multiline = True
                    line = line.lstrip('/* ').rstrip()
                    if '&' in colnames:
                        colnames = colnames.split(sep='&').lower()
                        for cn in colnames:
                            cn = cn.strip()
                            data_dict[cn] = data_dict[cn] + line
                            log.info('Appending Field Description for column {}'.format(cn))
                    else:
                        data_dict[colnames] = data_dict[colnames] + desc
                        log.info('Appending Field Description for column {}'.format(colnames))
                # The term "value" marks the beginning of a value constraint section
                elif line.startswith('value'):
                    confline = True
                    parameters = dict()
                    line = line.split(' ')
                    varname = line[1].rstrip('l')
                # In the section each constraint is assigned with a "="
                elif ('=' in line and confline == True):
                    line = line.split('=')
                    key = line[0].strip().strip('\'')
                    value = line[1].strip().strip('\'')
                    data_dict[(varname, key)] = value
                    logging.info('Getting parameter value for variable {}: {} {}'.format(varname, key, value))
                # An empty line marks the end of the constraint section
                elif len(line) == 0:
                    confline = False
                else:
                    next
    return data_dict

result_dict = get_sas_definitions(file_name)

# %%
for key, value in result_dict.items():
    if type(key) == tuple:
        print(key[0], ';', key[1], ';', value)
# Out:
# i94cnty ; 582 ; MEXICO Air Sea, and Not Reported (I-94, no land arrivals)
# i94cnty ; 236 ; AFGHANISTAN
# i94cnty ; 101 ; ALBANIA
# i94cnty ; 316 ; ALGERIA
# i94cnty ; 102 ; ANDORRA
# i94cnty ; 324 ; ANGOLA
# i94cnty ; 529 ; ANGUILLA
# i94cnty ; 518 ; ANTIGUA-BARBUDA
# i94cnty ; 687 ; ARGENTINA
# i94cnty ; 151 ; ARMENIA
# i94cnty ; 532 ; ARUBA
# i94cnty ; 438 ; AUSTRALIA
# i94cnty ; 103 ; AUSTRIA
# i94cnty ; 152 ; AZERBAIJAN
# i94cnty ; 512 ; BAHAMAS
# i94cnty ; 298 ; BAHRAIN
# i94cnty ; 274 ; BANGLADESH
# i94cnty ; 513 ; BARBADOS
# i94cnty ; 104 ; BELGIUM
# i94cnty ; 581 ; BELIZE
# i94cnty ; 386 ; BENIN
# i94cnty ; 509 ; BERMUDA
# i94cnty ; 153 ; BELARUS
# i94cnty ; 242 ; BHUTAN
# i94cnty ; 688 ; BOLIVIA
# i94cnty ; 717 ; BONAIRE, ST EUSTATIUS, SABA
# i94cnty ; 164 ; BOSNIA-HERZEGOVINA
# i94cnty ; 336 ; BOTSWANA
# i94cnty ; 689 ; BRAZIL
# i94cnty ; 525 ; BRITISH VIRGIN ISLANDS
# i94cnty ; 217 ; BRUNEI
# i94cnty ; 105 ; BULGARIA
# i94cnty ; 393 ; BURKINA FASO
# i94cnty ; 243 ; BURMA
# i94cnty ; 375 ; BURUNDI
# i94cnty ; 310 ; CAMEROON
# i94cnty ; 326 ; CAPE VERDE
# i94cnty ; 526 ; CAYMAN ISLANDS
# i94cnty ; 383 ; CENTRAL AFRICAN REPUBLIC
# i94cnty ; 384 ; CHAD
# i94cnty ; 690 ; CHILE
# i94cnty ; 245 ; CHINA, PRC
# i94cnty ; 721 ; CURACAO
# i94cnty ; 270 ; CHRISTMAS ISLAND
# i94cnty ; 271 ; COCOS ISLANDS
# i94cnty ; 691 ; COLOMBIA
# i94cnty ; 317 ; COMOROS
# i94cnty ; 385 ; CONGO
# i94cnty ; 467 ; COOK ISLANDS
# i94cnty ; 575 ; COSTA RICA
# i94cnty ; 165 ; CROATIA
# i94cnty ; 584 ; CUBA
# i94cnty ; 218 ; CYPRUS
# i94cnty ; 140 ; CZECH REPUBLIC
# i94cnty ; 723 ; FAROE ISLANDS (PART OF DENMARK)
# i94cnty ; 108 ; DENMARK
# i94cnty ; 322 ; DJIBOUTI
# i94cnty ; 519 ; DOMINICA
# i94cnty ; 585 ; DOMINICAN REPUBLIC
# i94cnty ; 240 ; EAST TIMOR
# i94cnty ; 692 ; ECUADOR
# i94cnty ; 368 ; EGYPT
# i94cnty ; 576 ; EL SALVADOR
# i94cnty ; 399 ; EQUATORIAL GUINEA
# i94cnty ; 372 ; ERITREA
# i94cnty ; 109 ; ESTONIA
# i94cnty ; 369 ; ETHIOPIA
# i94cnty ; 604 ; FALKLAND ISLANDS
# i94cnty ; 413 ; FIJI
# i94cnty ; 110 ; FINLAND
# i94cnty ; 111 ; FRANCE
# i94cnty ; 601 ; FRENCH GUIANA
# i94cnty ; 411 ; FRENCH POLYNESIA
# i94cnty ; 387 ; GABON
# i94cnty ; 338 ; GAMBIA
# i94cnty ; 758 ; GAZA STRIP
# i94cnty ; 154 ; GEORGIA
# i94cnty ; 112 ; GERMANY
# i94cnty ; 339 ; GHANA
# i94cnty ; 143 ; GIBRALTAR
# i94cnty ; 113 ; GREECE
# i94cnty ; 520 ; GRENADA
# i94cnty ; 507 ; GUADELOUPE
# i94cnty ; 577 ; GUATEMALA
# i94cnty ; 382 ; GUINEA
# i94cnty ; 327 ; GUINEA-BISSAU
# i94cnty ; 603 ; GUYANA
# i94cnty ; 586 ; HAITI
# i94cnty ; 726 ; HEARD AND MCDONALD IS.
# i94cnty ; 149 ; HOLY SEE/VATICAN
# i94cnty ; 528 ; HONDURAS
# i94cnty ; 206 ; HONG KONG
# i94cnty ; 114 ; HUNGARY
# i94cnty ; 115 ; ICELAND
# i94cnty ; 213 ; INDIA
# i94cnty ; 759 ; INDIAN OCEAN AREAS (FRENCH)
# i94cnty ; 729 ; INDIAN OCEAN TERRITORY
# i94cnty ; 204 ; INDONESIA
# i94cnty ; 249 ; IRAN
# i94cnty ; 250 ; IRAQ
# i94cnty ; 116 ; IRELAND
# i94cnty ; 251 ; ISRAEL
# i94cnty ; 117 ; ITALY
# i94cnty ; 388 ; IVORY COAST
# i94cnty ; 514 ; JAMAICA
# i94cnty ; 209 ; JAPAN
# i94cnty ; 253 ; JORDAN
# i94cnty ; 201 ; KAMPUCHEA
# i94cnty ; 155 ; KAZAKHSTAN
# i94cnty ; 340 ; KENYA
# i94cnty ; 414 ; KIRIBATI
# i94cnty ; 732 ; KOSOVO
# i94cnty ; 272 ; KUWAIT
# i94cnty ; 156 ; KYRGYZSTAN
# i94cnty ; 203 ; LAOS
# i94cnty ; 118 ; LATVIA
# i94cnty ; 255 ; LEBANON
# i94cnty ; 335 ; LESOTHO
# i94cnty ; 370 ; LIBERIA
# i94cnty ; 381 ; LIBYA
# i94cnty ; 119 ; LIECHTENSTEIN
# i94cnty ; 120 ; LITHUANIA
# i94cnty ; 121 ; LUXEMBOURG
# i94cnty ; 214 ; MACAU
# i94cnty ; 167 ; MACEDONIA
# i94cnty ; 320 ; MADAGASCAR
# i94cnty ; 345 ; MALAWI
# i94cnty ; 273 ; MALAYSIA
# i94cnty ; 220 ; MALDIVES
# i94cnty ; 392 ; MALI
# i94cnty ; 145 ; MALTA
# i94cnty ; 472 ; MARSHALL ISLANDS
# i94cnty ; 511 ; MARTINIQUE
# i94cnty ; 389 ; MAURITANIA
# i94cnty ; 342 ; MAURITIUS
# i94cnty ; 760 ; MAYOTTE (AFRICA - FRENCH)
# i94cnty ; 473 ; MICRONESIA, FED. STATES OF
# i94cnty ; 157 ; MOLDOVA
# i94cnty ; 122 ; MONACO
# i94cnty ; 299 ; MONGOLIA
# i94cnty ; 735 ; MONTENEGRO
# i94cnty ; 521 ; MONTSERRAT
# i94cnty ; 332 ; MOROCCO
# i94cnty ; 329 ; MOZAMBIQUE
# i94cnty ; 371 ; NAMIBIA
# i94cnty ; 440 ; NAURU
# i94cnty ; 257 ; NEPAL
# i94cnty ; 123 ; NETHERLANDS
# i94cnty ; 508 ; NETHERLANDS ANTILLES
# i94cnty ; 409 ; NEW CALEDONIA
# i94cnty ; 464 ; NEW ZEALAND
# i94cnty ; 579 ; NICARAGUA
# i94cnty ; 390 ; NIGER
# i94cnty ; 343 ; NIGERIA
# i94cnty ; 470 ; NIUE
# i94cnty ; 275 ; NORTH KOREA
# i94cnty ; 124 ; NORWAY
# i94cnty ; 256 ; OMAN
# i94cnty ; 258 ; PAKISTAN
# i94cnty ; 474 ; PALAU
# i94cnty ; 743 ; PALESTINE
# i94cnty ; 504 ; PANAMA
# i94cnty ; 441 ; PAPUA NEW GUINEA
# i94cnty ; 693 ; PARAGUAY
# i94cnty ; 694 ; PERU
# i94cnty ; 260 ; PHILIPPINES
# i94cnty ; 416 ; PITCAIRN ISLANDS
# i94cnty ; 107 ; POLAND
# i94cnty ; 126 ; PORTUGAL
# i94cnty ; 297 ; QATAR
# i94cnty ; 748 ; REPUBLIC OF SOUTH SUDAN
# i94cnty ; 321 ; REUNION
# i94cnty ; 127 ; ROMANIA
# i94cnty ; 158 ; RUSSIA
# i94cnty ; 376 ; RWANDA
# i94cnty ; 128 ; SAN MARINO
# i94cnty ; 330 ; SAO TOME AND PRINCIPE
# i94cnty ; 261 ; SAUDI ARABIA
# i94cnty ; 391 ; SENEGAL
# i94cnty ; 142 ; SERBIA AND MONTENEGRO
# i94cnty ; 745 ; SERBIA
# i94cnty ; 347 ; SEYCHELLES
# i94cnty ; 348 ; SIERRA LEONE
# i94cnty ; 207 ; SINGAPORE
# i94cnty ; 141 ; SLOVAKIA
# i94cnty ; 166 ; SLOVENIA
# i94cnty ; 412 ; SOLOMON ISLANDS
# i94cnty ; 397 ; SOMALIA
# i94cnty ; 373 ; SOUTH AFRICA
# i94cnty ; 276 ; SOUTH KOREA
# i94cnty ; 129 ; SPAIN
# i94cnty ; 244 ; SRI LANKA
# i94cnty ; 346 ; ST. HELENA
# i94cnty ; 522 ; ST. KITTS-NEVIS
# i94cnty ; 523 ; ST. LUCIA
# i94cnty ; 502 ; ST. PIERRE AND MIQUELON
# i94cnty ; 524 ; ST. VINCENT-GRENADINES
# i94cnty ; 716 ; SAINT BARTHELEMY
# i94cnty ; 736 ; SAINT MARTIN
# i94cnty ; 749 ; SAINT MAARTEN
# i94cnty ; 350 ; SUDAN
# i94cnty ; 602 ; SURINAME
# i94cnty ; 351 ; SWAZILAND
# i94cnty ; 130 ; SWEDEN
# i94cnty ; 131 ; SWITZERLAND
# i94cnty ; 262 ; SYRIA
# i94cnty ; 268 ; TAIWAN
# i94cnty ; 159 ; TAJIKISTAN
# i94cnty ; 353 ; TANZANIA
# i94cnty ; 263 ; THAILAND
# i94cnty ; 304 ; TOGO
# i94cnty ; 417 ; TONGA
# i94cnty ; 516 ; TRINIDAD AND TOBAGO
# i94cnty ; 323 ; TUNISIA
# i94cnty ; 264 ; TURKEY
# i94cnty ; 161 ; TURKMENISTAN
# i94cnty ; 527 ; TURKS AND CAICOS ISLANDS
# i94cnty ; 420 ; TUVALU
# i94cnty ; 352 ; UGANDA
# i94cnty ; 162 ; UKRAINE
# i94cnty ; 296 ; UNITED ARAB EMIRATES
# i94cnty ; 135 ; UNITED KINGDOM
# i94cnty ; 695 ; URUGUAY
# i94cnty ; 163 ; UZBEKISTAN
# i94cnty ; 410 ; VANUATU
# i94cnty ; 696 ; VENEZUELA
# i94cnty ; 266 ; VIETNAM
# i94cnty ; 469 ; WALLIS AND FUTUNA ISLANDS
# i94cnty ; 757 ; WEST INDIES (FRENCH)
# i94cnty ; 333 ; WESTERN SAHARA
# i94cnty ; 465 ; WESTERN SAMOA
# i94cnty ; 216 ; YEMEN
# i94cnty ; 139 ; YUGOSLAVIA
# i94cnty ; 301 ; ZAIRE
# i94cnty ; 344 ; ZAMBIA
# i94cnty ; 315 ; ZIMBABWE
# i94cnty ; 403 ; INVALID: AMERICAN SAMOA
# i94cnty ; 712 ; INVALID: ANTARCTICA
# i94cnty ; 700 ; INVALID: BORN ON BOARD SHIP
# i94cnty ; 719 ; INVALID: BOUVET ISLAND (ANTARCTICA/NORWAY TERR.)
# i94cnty ; 574 ; INVALID: CANADA
# i94cnty ; 720 ; INVALID: CANTON AND ENDERBURY ISLS
# i94cnty ; 106 ; INVALID: CZECHOSLOVAKIA
# i94cnty ; 739 ; INVALID: DRONNING MAUD LAND (ANTARCTICA-NORWAY)
# i94cnty ; 394 ; INVALID: FRENCH SOUTHERN AND ANTARCTIC
# i94cnty ; 501 ; INVALID: GREENLAND
# i94cnty ; 404 ; INVALID: GUAM
# i94cnty ; 730 ; INVALID: INTERNATIONAL WATERS
# i94cnty ; 731 ; INVALID: JOHNSON ISLAND
# i94cnty ; 471 ; INVALID: MARIANA ISLANDS, NORTHERN
# i94cnty ; 737 ; INVALID: MIDWAY ISLANDS
# i94cnty ; 753 ; INVALID: MINOR OUTLYING ISLANDS - USA
# i94cnty ; 740 ; INVALID: NEUTRAL ZONE (S. ARABIA/IRAQ)
# i94cnty ; 710 ; INVALID: NON-QUOTA IMMIGRANT
# i94cnty ; 505 ; INVALID: PUERTO RICO
# i94cnty ; 0 ; INVALID: STATELESS
# i94cnty ; 705 ; INVALID: STATELESS
# i94cnty ; 583 ; INVALID: UNITED STATES
# i94cnty ; 407 ; INVALID: UNITED STATES
# i94cnty ; 999 ; INVALID: UNKNOWN
# i94cnty ; 239 ; INVALID: UNKNOWN COUNTRY
# i94cnty ; 134 ; INVALID: USSR
# i94cnty ; 506 ; INVALID: U.S. VIRGIN ISLANDS
# i94cnty ; 755 ; INVALID: WAKE ISLAND
# i94cnty ; 311 ; Collapsed Tanzania (should not show)
# i94cnty ; 741 ; Collapsed Curacao (should not show)
# i94cnty ; 54 ; No Country Code (54)
# i94cnty ; 100 ; No Country Code (100)
# i94cnty ; 187 ; No Country Code (187)
# i94cnty ; 190 ; No Country Code (190)
# i94cnty ; 200 ; No Country Code (200)
# i94cnty ; 219 ; No Country Code (219)
# i94cnty ; 238 ; No Country Code (238)
# i94cnty ; 277 ; No Country Code (277)
# i94cnty ; 293 ; No Country Code (293)
# i94cnty ; 300 ; No Country Code (300)
# i94cnty ; 319 ; No Country Code (319)
# i94cnty ; 365 ; No Country Code (365)
# i94cnty ; 395 ; No Country Code (395)
# i94cnty ; 400 ; No Country Code (400)
# i94cnty ; 485 ; No Country Code (485)
# i94cnty ; 503 ; No Country Code (503)
# i94cnty ; 589 ; No Country Code (589)
# i94cnty ; 592 ; No Country Code (592)
# i94cnty ; 791 ; No Country Code (791)
# i94cnty ; 849 ; No Country Code (849)
# i94cnty ; 914 ; No Country Code (914)
# i94cnty ; 944 ; No Country Code (944)
# i94cnty ; 996 ; No Country Code (996)' ;
# $i94prt ; ALC ; ALCAN, AK
# $i94prt ; ANC ; ANCHORAGE, AK
# $i94prt ; BAR ; BAKER AAF - BAKER ISLAND, AK
# $i94prt ; DAC ; DALTONS CACHE, AK
# $i94prt ; PIZ ; DEW STATION PT LAY DEW, AK
# $i94prt ; DTH ; DUTCH HARBOR, AK
# $i94prt ; EGL ; EAGLE, AK
# $i94prt ; FRB ; FAIRBANKS, AK
# $i94prt ; HOM ; HOMER, AK
# $i94prt ; HYD ; HYDER, AK
# $i94prt ; JUN ; JUNEAU, AK
# $i94prt ; 5KE ; KETCHIKAN, AK
# $i94prt ; KET ; KETCHIKAN, AK
# $i94prt ; MOS ; MOSES POINT INTERMEDIATE, AK
# $i94prt ; NIK ; NIKISKI, AK
# $i94prt ; NOM ; NOM, AK
# $i94prt ; PKC ; POKER CREEK, AK
# $i94prt ; ORI ; PORT LIONS SPB, AK
# $i94prt ; SKA ; SKAGWAY, AK
# $i94prt ; SNP ; ST. PAUL ISLAND, AK
# $i94prt ; TKI ; TOKEEN, AK
# $i94prt ; WRA ; WRANGELL, AK
# $i94prt ; HSV ; MADISON COUNTY - HUNTSVILLE, AL
# $i94prt ; MOB ; MOBILE, AL
# $i94prt ; LIA ; LITTLE ROCK, AR (BPS)
# $i94prt ; ROG ; ROGERS ARPT, AR
# $i94prt ; DOU ; DOUGLAS, AZ
# $i94prt ; LUK ; LUKEVILLE, AZ
# $i94prt ; MAP ; MARIPOSA AZ
# $i94prt ; NAC ; NACO, AZ
# $i94prt ; NOG ; NOGALES, AZ
# $i94prt ; PHO ; PHOENIX, AZ
# $i94prt ; POR ; PORTAL, AZ
# $i94prt ; SLU ; SAN LUIS, AZ
# $i94prt ; SAS ; SASABE, AZ
# $i94prt ; TUC ; TUCSON, AZ
# $i94prt ; YUI ; YUMA, AZ
# $i94prt ; AND ; ANDRADE, CA
# $i94prt ; BUR ; BURBANK, CA
# $i94prt ; CAL ; CALEXICO, CA
# $i94prt ; CAO ; CAMPO, CA
# $i94prt ; FRE ; FRESNO, CA
# $i94prt ; ICP ; IMPERIAL COUNTY, CA
# $i94prt ; LNB ; LONG BEACH, CA
# $i94prt ; LOS ; LOS ANGELES, CA
# $i94prt ; BFL ; MEADOWS FIELD - BAKERSFIELD, CA
# $i94prt ; OAK ; OAKLAND, CA
# $i94prt ; ONT ; ONTARIO, CA
# $i94prt ; OTM ; OTAY MESA, CA
# $i94prt ; BLT ; PACIFIC, HWY. STATION, CA
# $i94prt ; PSP ; PALM SPRINGS, CA
# $i94prt ; SAC ; SACRAMENTO, CA
# $i94prt ; SLS ; SALINAS, CA (BPS)
# $i94prt ; SDP ; SAN DIEGO, CA
# $i94prt ; SFR ; SAN FRANCISCO, CA
# $i94prt ; SNJ ; SAN JOSE, CA
# $i94prt ; SLO ; SAN LUIS OBISPO, CA
# $i94prt ; SLI ; SAN LUIS OBISPO, CA (BPS)
# $i94prt ; SPC ; SAN PEDRO, CA
# $i94prt ; SYS ; SAN YSIDRO, CA
# $i94prt ; SAA ; SANTA ANA, CA
# $i94prt ; STO ; STOCKTON, CA (BPS)
# $i94prt ; TEC ; TECATE, CA
# $i94prt ; TRV ; TRAVIS-AFB, CA
# $i94prt ; APA ; ARAPAHOE COUNTY, CO
# $i94prt ; ASE ; ASPEN, CO #ARPT
# $i94prt ; COS ; COLORADO SPRINGS, CO
# $i94prt ; DEN ; DENVER, CO
# $i94prt ; DRO ; LA PLATA - DURANGO, CO
# $i94prt ; BDL ; BRADLEY INTERNATIONAL, CT
# $i94prt ; BGC ; BRIDGEPORT, CT
# $i94prt ; GRT ; GROTON, CT
# $i94prt ; HAR ; HARTFORD, CT
# $i94prt ; NWH ; NEW HAVEN, CT
# $i94prt ; NWL ; NEW LONDON, CT
# $i94prt ; TST ; NEWINGTON DATA CENTER TEST, CT
# $i94prt ; WAS ; WASHINGTON DC
# $i94prt ; DOV ; DOVER AFB, DE
# $i94prt ; DVD ; DOVER-AFB, DE
# $i94prt ; WLL ; WILMINGTON, DE
# $i94prt ; BOC ; BOCAGRANDE, FL
# $i94prt ; SRQ ; BRADENTON - SARASOTA, FL
# $i94prt ; CAN ; CAPE CANAVERAL, FL
# $i94prt ; DAB ; DAYTONA BEACH INTERNATIONAL, FL
# $i94prt ; FRN ; FERNANDINA, FL
# $i94prt ; FTL ; FORT LAUDERDALE, FL
# $i94prt ; FMY ; FORT MYERS, FL
# $i94prt ; FPF ; FORT PIERCE, FL
# $i94prt ; HUR ; HURLBURT FIELD, FL
# $i94prt ; GNV ; J R ALISON MUNI - GAINESVILLE, FL
# $i94prt ; JAC ; JACKSONVILLE, FL
# $i94prt ; KEY ; KEY WEST, FL
# $i94prt ; LEE ; LEESBURG MUNICIPAL AIRPORT, FL
# $i94prt ; MLB ; MELBOURNE, FL
# $i94prt ; MIA ; MIAMI, FL
# $i94prt ; APF ; NAPLES, FL #ARPT
# $i94prt ; OPF ; OPA LOCKA, FL
# $i94prt ; ORL ; ORLANDO, FL
# $i94prt ; PAN ; PANAMA CITY, FL
# $i94prt ; PEN ; PENSACOLA, FL
# $i94prt ; PCF ; PORT CANAVERAL, FL
# $i94prt ; PEV ; PORT EVERGLADES, FL
# $i94prt ; PSJ ; PORT ST JOE, FL
# $i94prt ; SFB ; SANFORD, FL
# $i94prt ; SGJ ; ST AUGUSTINE ARPT, FL
# $i94prt ; SAU ; ST AUGUSTINE, FL
# $i94prt ; FPR ; ST LUCIE COUNTY, FL
# $i94prt ; SPE ; ST PETERSBURG, FL
# $i94prt ; TAM ; TAMPA, FL
# $i94prt ; WPB ; WEST PALM BEACH, FL
# $i94prt ; ATL ; ATLANTA, GA
# $i94prt ; BRU ; BRUNSWICK, GA
# $i94prt ; AGS ; BUSH FIELD - AUGUSTA, GA
# $i94prt ; SAV ; SAVANNAH, GA
# $i94prt ; AGA ; AGANA, GU
# $i94prt ; HHW ; HONOLULU, HI
# $i94prt ; OGG ; KAHULUI - MAUI, HI
# $i94prt ; KOA ; KEAHOLE-KONA, HI
# $i94prt ; LIH ; LIHUE, HI
# $i94prt ; CID ; CEDAR RAPIDS/IOWA CITY, IA
# $i94prt ; DSM ; DES MOINES, IA
# $i94prt ; BOI ; AIR TERM. (GOWEN FLD) BOISE, ID
# $i94prt ; EPI ; EASTPORT, ID
# $i94prt ; IDA ; FANNING FIELD - IDAHO FALLS, ID
# $i94prt ; PTL ; PORTHILL, ID
# $i94prt ; SPI ; CAPITAL - SPRINGFIELD, IL
# $i94prt ; CHI ; CHICAGO, IL
# $i94prt ; DPA ; DUPAGE COUNTY, IL
# $i94prt ; PIA ; GREATER PEORIA, IL
# $i94prt ; RFD ; GREATER ROCKFORD, IL
# $i94prt ; UGN ; MEMORIAL - WAUKEGAN, IL
# $i94prt ; GAR ; GARY, IN
# $i94prt ; HMM ; HAMMOND, IN
# $i94prt ; INP ; INDIANAPOLIS, IN
# $i94prt ; MRL ; MERRILLVILLE, IN
# $i94prt ; SBN ; SOUTH BEND, IN
# $i94prt ; ICT ; MID-CONTINENT - WITCHITA, KS
# $i94prt ; LEX ; BLUE GRASS - LEXINGTON, KY
# $i94prt ; LOU ; LOUISVILLE, KY
# $i94prt ; BTN ; BATON ROUGE, LA
# $i94prt ; LKC ; LAKE CHARLES, LA
# $i94prt ; LAK ; LAKE CHARLES, LA (BPS)
# $i94prt ; MLU ; MONROE, LA
# $i94prt ; MGC ; MORGAN CITY, LA
# $i94prt ; NOL ; NEW ORLEANS, LA
# $i94prt ; BOS ; BOSTON, MA
# $i94prt ; GLO ; GLOUCESTER, MA
# $i94prt ; BED ; HANSCOM FIELD - BEDFORD, MA
# $i94prt ; LYN ; LYNDEN, WA
# $i94prt ; ADW ; ANDREWS AFB, MD
# $i94prt ; BAL ; BALTIMORE, MD
# $i94prt ; MKG ; MUSKEGON, MD
# $i94prt ; PAX ; PATUXENT RIVER, MD
# $i94prt ; BGM ; BANGOR, ME
# $i94prt ; BOO ; BOOTHBAY HARBOR, ME
# $i94prt ; BWM ; BRIDGEWATER, ME
# $i94prt ; BCK ; BUCKPORT, ME
# $i94prt ; CLS ; CALAIS, ME
# $i94prt ; CRB ; CARIBOU, ME
# $i94prt ; COB ; COBURN GORE, ME
# $i94prt ; EST ; EASTCOURT, ME
# $i94prt ; EPT ; EASTPORT MUNICIPAL, ME
# $i94prt ; EPM ; EASTPORT, ME
# $i94prt ; FOR ; FOREST CITY, ME
# $i94prt ; FTF ; FORT FAIRFIELD, ME
# $i94prt ; FTK ; FORT KENT, ME
# $i94prt ; HML ; HAMIIN, ME
# $i94prt ; HTM ; HOULTON, ME
# $i94prt ; JKM ; JACKMAN, ME
# $i94prt ; KAL ; KALISPEL, MT
# $i94prt ; LIM ; LIMESTONE, ME
# $i94prt ; LUB ; LUBEC, ME
# $i94prt ; MAD ; MADAWASKA, ME
# $i94prt ; POM ; PORTLAND, ME
# $i94prt ; RGM ; RANGELEY, ME (BPS)
# $i94prt ; SBR ; SOUTH BREWER, ME
# $i94prt ; SRL ; ST AURELIE, ME
# $i94prt ; SPA ; ST PAMPILE, ME
# $i94prt ; VNB ; VAN BUREN, ME
# $i94prt ; VCB ; VANCEBORO, ME
# $i94prt ; AGN ; ALGONAC, MI
# $i94prt ; ALP ; ALPENA, MI
# $i94prt ; BCY ; BAY CITY, MI
# $i94prt ; DET ; DETROIT, MI
# $i94prt ; GRP ; GRAND RAPIDS, MI
# $i94prt ; GRO ; GROSSE ISLE, MI
# $i94prt ; ISL ; ISLE ROYALE, MI
# $i94prt ; MRC ; MARINE CITY, MI
# $i94prt ; MRY ; MARYSVILLE, MI
# $i94prt ; PTK ; OAKLAND COUNTY - PONTIAC, MI
# $i94prt ; PHU ; PORT HURON, MI
# $i94prt ; RBT ; ROBERTS LANDING, MI
# $i94prt ; SAG ; SAGINAW, MI
# $i94prt ; SSM ; SAULT STE. MARIE, MI
# $i94prt ; SCL ; ST CLAIR, MI
# $i94prt ; YIP ; WILLOW RUN - YPSILANTI, MI
# $i94prt ; BAU ; BAUDETTE, MN
# $i94prt ; CAR ; CARIBOU MUNICIPAL AIRPORT, MN
# $i94prt ; GTF ; Collapsed into INT, MN
# $i94prt ; INL ; Collapsed into INT, MN
# $i94prt ; CRA ; CRANE LAKE, MN
# $i94prt ; MIC ; CRYSTAL MUNICIPAL AIRPORT, MN
# $i94prt ; DUL ; DULUTH, MN
# $i94prt ; ELY ; ELY, MN
# $i94prt ; GPM ; GRAND PORTAGE, MN
# $i94prt ; SVC ; GRANT COUNTY - SILVER CITY, MN
# $i94prt ; INT ; INT''L FALLS, MN
# $i94prt ; LAN ; LANCASTER, MN
# $i94prt ; MSP ; MINN./ST PAUL, MN
# $i94prt ; LIN ; NORTHERN SVC CENTER, MN
# $i94prt ; NOY ; NOYES, MN
# $i94prt ; PIN ; PINE CREEK, MN
# $i94prt ; 48Y ; PINECREEK BORDER ARPT, MN
# $i94prt ; RAN ; RAINER, MN
# $i94prt ; RST ; ROCHESTER, MN
# $i94prt ; ROS ; ROSEAU, MN
# $i94prt ; SPM ; ST PAUL, MN
# $i94prt ; WSB ; WARROAD INTL, SPB, MN
# $i94prt ; WAR ; WARROAD, MN
# $i94prt ; KAN ; KANSAS CITY, MO
# $i94prt ; SGF ; SPRINGFIELD-BRANSON, MO
# $i94prt ; STL ; ST LOUIS, MO
# $i94prt ; WHI ; WHITETAIL, MT
# $i94prt ; WHM ; WILD HORSE, MT
# $i94prt ; GPT ; BILOXI REGIONAL, MS
# $i94prt ; GTR ; GOLDEN TRIANGLE LOWNDES CNTY, MS
# $i94prt ; GUL ; GULFPORT, MS
# $i94prt ; PAS ; PASCAGOULA, MS
# $i94prt ; JAN ; THOMPSON FIELD - JACKSON, MS
# $i94prt ; BIL ; BILLINGS, MT
# $i94prt ; BTM ; BUTTE, MT
# $i94prt ; CHF ; CHIEF MT, MT
# $i94prt ; CTB ; CUT BANK MUNICIPAL, MT
# $i94prt ; CUT ; CUT BANK, MT
# $i94prt ; DLB ; DEL BONITA, MT
# $i94prt ; EUR ; EUREKA, MT (BPS)
# $i94prt ; BZN ; GALLATIN FIELD - BOZEMAN, MT
# $i94prt ; FCA ; GLACIER NATIONAL PARK, MT
# $i94prt ; GGW ; GLASGOW, MT
# $i94prt ; GRE ; GREAT FALLS, MT
# $i94prt ; HVR ; HAVRE, MT
# $i94prt ; HEL ; HELENA, MT
# $i94prt ; LWT ; LEWISTON, MT
# $i94prt ; MGM ; MORGAN, MT
# $i94prt ; OPH ; OPHEIM, MT
# $i94prt ; PIE ; PIEGAN, MT
# $i94prt ; RAY ; RAYMOND, MT
# $i94prt ; ROO ; ROOSVILLE, MT
# $i94prt ; SCO ; SCOBEY, MT
# $i94prt ; SWE ; SWEETGTASS, MT
# $i94prt ; TRL ; TRIAL CREEK, MT
# $i94prt ; TUR ; TURNER, MT
# $i94prt ; WCM ; WILLOW CREEK, MT
# $i94prt ; CLT ; CHARLOTTE, NC
# $i94prt ; FAY ; FAYETTEVILLE, NC
# $i94prt ; MRH ; MOREHEAD CITY, NC
# $i94prt ; FOP ; MORRIS FIELDS AAF, NC
# $i94prt ; GSO ; PIEDMONT TRIAD INTL AIRPORT, NC
# $i94prt ; RDU ; RALEIGH/DURHAM, NC
# $i94prt ; SSC ; SHAW AFB - SUMTER, NC
# $i94prt ; WIL ; WILMINGTON, NC
# $i94prt ; AMB ; AMBROSE, ND
# $i94prt ; ANT ; ANTLER, ND
# $i94prt ; CRY ; CARBURY, ND
# $i94prt ; DNS ; DUNSEITH, ND
# $i94prt ; FAR ; FARGO, ND
# $i94prt ; FRT ; FORTUNA, ND
# $i94prt ; GRF ; GRAND FORKS, ND
# $i94prt ; HNN ; HANNAH, ND
# $i94prt ; HNS ; HANSBORO, ND
# $i94prt ; MAI ; MAIDA, ND
# $i94prt ; MND ; MINOT, ND
# $i94prt ; NEC ; NECHE, ND
# $i94prt ; NOO ; NOONAN, ND
# $i94prt ; NRG ; NORTHGATE, ND
# $i94prt ; PEM ; PEMBINA, ND
# $i94prt ; SAR ; SARLES, ND
# $i94prt ; SHR ; SHERWOOD, ND
# $i94prt ; SJO ; ST JOHN, ND
# $i94prt ; WAL ; WALHALLA, ND
# $i94prt ; WHO ; WESTHOPE, ND
# $i94prt ; WND ; WILLISTON, ND
# $i94prt ; OMA ; OMAHA, NE
# $i94prt ; LEB ; LEBANON, NH
# $i94prt ; MHT ; MANCHESTER, NH
# $i94prt ; PNH ; PITTSBURG, NH
# $i94prt ; PSM ; PORTSMOUTH, NH
# $i94prt ; BYO ; BAYONNE, NJ
# $i94prt ; CNJ ; CAMDEN, NJ
# $i94prt ; HOB ; HOBOKEN, NJ
# $i94prt ; JER ; JERSEY CITY, NJ
# $i94prt ; WRI ; MC GUIRE AFB - WRIGHTSOWN, NJ
# $i94prt ; MMU ; MORRISTOWN, NJ
# $i94prt ; NEW ; NEWARK/TETERBORO, NJ
# $i94prt ; PER ; PERTH AMBOY, NJ
# $i94prt ; ACY ; POMONA FIELD - ATLANTIC CITY, NJ
# $i94prt ; ALA ; ALAMAGORDO, NM (BPS)
# $i94prt ; ABQ ; ALBUQUERQUE, NM
# $i94prt ; ANP ; ANTELOPE WELLS, NM
# $i94prt ; CRL ; CARLSBAD, NM
# $i94prt ; COL ; COLUMBUS, NM
# $i94prt ; CDD ; CRANE LAKE - ST. LOUIS CNTY, NM
# $i94prt ; DNM ; DEMING, NM (BPS)
# $i94prt ; LAS ; LAS CRUCES, NM
# $i94prt ; LOB ; LORDSBURG, NM (BPS)
# $i94prt ; RUI ; RUIDOSO, NM
# $i94prt ; STR ; SANTA TERESA, NM
# $i94prt ; RNO ; CANNON INTL - RENO/TAHOE, NV
# $i94prt ; FLX ; FALLON MUNICIPAL AIRPORT, NV
# $i94prt ; LVG ; LAS VEGAS, NV
# $i94prt ; REN ; RENO, NV
# $i94prt ; ALB ; ALBANY, NY
# $i94prt ; AXB ; ALEXANDRIA BAY, NY
# $i94prt ; BUF ; BUFFALO, NY
# $i94prt ; CNH ; CANNON CORNERS, NY
# $i94prt ; CAP ; CAPE VINCENT, NY
# $i94prt ; CHM ; CHAMPLAIN, NY
# $i94prt ; CHT ; CHATEAUGAY, NY
# $i94prt ; CLA ; CLAYTON, NY
# $i94prt ; FTC ; FORT COVINGTON, NY
# $i94prt ; LAG ; LA GUARDIA, NY
# $i94prt ; LEW ; LEWISTON, NY
# $i94prt ; MAS ; MASSENA, NY
# $i94prt ; MAG ; MCGUIRE AFB, NY
# $i94prt ; MOO ; MOORES, NY
# $i94prt ; MRR ; MORRISTOWN, NY
# $i94prt ; NYC ; NEW YORK, NY
# $i94prt ; NIA ; NIAGARA FALLS, NY
# $i94prt ; OGD ; OGDENSBURG, NY
# $i94prt ; OSW ; OSWEGO, NY
# $i94prt ; ELM ; REGIONAL ARPT - HORSEHEAD, NY
# $i94prt ; ROC ; ROCHESTER, NY
# $i94prt ; ROU ; ROUSES POINT, NY
# $i94prt ; SWF ; STEWART - ORANGE CNTY, NY
# $i94prt ; SYR ; SYRACUSE, NY
# $i94prt ; THO ; THOUSAND ISLAND BRIDGE, NY
# $i94prt ; TRO ; TROUT RIVER, NY
# $i94prt ; WAT ; WATERTOWN, NY
# $i94prt ; HPN ; WESTCHESTER - WHITE PLAINS, NY
# $i94prt ; WRB ; WHIRLPOOL BRIDGE, NY
# $i94prt ; YOU ; YOUNGSTOWN, NY
# $i94prt ; AKR ; AKRON, OH
# $i94prt ; ATB ; ASHTABULA, OH
# $i94prt ; CIN ; CINCINNATI, OH
# $i94prt ; CLE ; CLEVELAND, OH
# $i94prt ; CLM ; COLUMBUS, OH
# $i94prt ; LOR ; LORAIN, OH
# $i94prt ; MBO ; MARBLE HEADS, OH
# $i94prt ; SDY ; SANDUSKY, OH
# $i94prt ; TOL ; TOLEDO, OH
# $i94prt ; OKC ; OKLAHOMA CITY, OK
# $i94prt ; TUL ; TULSA, OK
# $i94prt ; AST ; ASTORIA, OR
# $i94prt ; COO ; COOS BAY, OR
# $i94prt ; HIO ; HILLSBORO, OR
# $i94prt ; MED ; MEDFORD, OR
# $i94prt ; NPT ; NEWPORT, OR
# $i94prt ; POO ; PORTLAND, OR
# $i94prt ; PUT ; PUT-IN-BAY, OH
# $i94prt ; RDM ; ROBERTS FIELDS - REDMOND, OR
# $i94prt ; ERI ; ERIE, PA
# $i94prt ; MDT ; HARRISBURG, PA
# $i94prt ; HSB ; HARRISONBURG, PA
# $i94prt ; PHI ; PHILADELPHIA, PA
# $i94prt ; PIT ; PITTSBURG, PA
# $i94prt ; AGU ; AGUADILLA, PR
# $i94prt ; BQN ; BORINQUEN - AGUADILLO, PR
# $i94prt ; JCP ; CULEBRA - BENJAMIN RIVERA, PR
# $i94prt ; ENS ; ENSENADA, PR
# $i94prt ; FAJ ; FAJARDO, PR
# $i94prt ; HUM ; HUMACAO, PR
# $i94prt ; JOB ; JOBOS, PR
# $i94prt ; MAY ; MAYAGUEZ, PR
# $i94prt ; PON ; PONCE, PR
# $i94prt ; PSE ; PONCE-MERCEDITA, PR
# $i94prt ; SAJ ; SAN JUAN, PR
# $i94prt ; VQS ; VIEQUES-ARPT, PR
# $i94prt ; PRO ; PROVIDENCE, RI
# $i94prt ; PVD ; THEODORE FRANCIS - WARWICK, RI
# $i94prt ; CHL ; CHARLESTON, SC
# $i94prt ; CAE ; COLUMBIA, SC #ARPT
# $i94prt ; GEO ; GEORGETOWN, SC
# $i94prt ; GSP ; GREENVILLE, SC
# $i94prt ; GRR ; GREER, SC
# $i94prt ; MYR ; MYRTLE BEACH, SC
# $i94prt ; SPF ; BLACK HILLS, SPEARFISH, SD
# $i94prt ; HON ; HOWES REGIONAL ARPT - HURON, SD
# $i94prt ; SAI ; SAIPAN, SPN
# $i94prt ; TYS ; MC GHEE TYSON - ALCOA, TN
# $i94prt ; MEM ; MEMPHIS, TN
# $i94prt ; NSV ; NASHVILLE, TN
# $i94prt ; TRI ; TRI CITY ARPT, TN
# $i94prt ; ADS ; ADDISON AIRPORT- ADDISON, TX
# $i94prt ; ADT ; AMISTAD DAM, TX
# $i94prt ; ANZ ; ANZALDUAS, TX
# $i94prt ; AUS ; AUSTIN, TX
# $i94prt ; BEA ; BEAUMONT, TX
# $i94prt ; BBP ; BIG BEND PARK, TX (BPS)
# $i94prt ; SCC ; BP SPEC COORD. CTR, TX
# $i94prt ; BTC ; BP TACTICAL UNIT, TX
# $i94prt ; BOA ; BRIDGE OF AMERICAS, TX
# $i94prt ; BRO ; BROWNSVILLE, TX
# $i94prt ; CRP ; CORPUS CHRISTI, TX
# $i94prt ; DAL ; DALLAS, TX
# $i94prt ; DLR ; DEL RIO, TX
# $i94prt ; DNA ; DONNA, TX
# $i94prt ; EGP ; EAGLE PASS, TX
# $i94prt ; ELP ; EL PASO, TX
# $i94prt ; FAB ; FABENS, TX
# $i94prt ; FAL ; FALCON HEIGHTS, TX
# $i94prt ; FTH ; FORT HANCOCK, TX
# $i94prt ; AFW ; FORT WORTH ALLIANCE, TX
# $i94prt ; FPT ; FREEPORT, TX
# $i94prt ; GAL ; GALVESTON, TX
# $i94prt ; HLG ; HARLINGEN, TX
# $i94prt ; HID ; HIDALGO, TX
# $i94prt ; HOU ; HOUSTON, TX
# $i94prt ; SGR ; HULL FIELD, SUGAR LAND ARPT, TX
# $i94prt ; LLB ; JUAREZ-LINCOLN BRIDGE, TX
# $i94prt ; LCB ; LAREDO COLUMBIA BRIDGE, TX
# $i94prt ; LRN ; LAREDO NORTH, TX
# $i94prt ; LAR ; LAREDO, TX
# $i94prt ; LSE ; LOS EBANOS, TX
# $i94prt ; IND ; LOS INDIOS, TX
# $i94prt ; LOI ; LOS INDIOS, TX
# $i94prt ; MRS ; MARFA, TX (BPS)
# $i94prt ; MCA ; MCALLEN, TX
# $i94prt ; MAF ; ODESSA REGIONAL, TX
# $i94prt ; PDN ; PASO DEL NORTE,TX
# $i94prt ; PBB ; PEACE BRIDGE, NY
# $i94prt ; PHR ; PHARR, TX
# $i94prt ; PAR ; PORT ARTHUR, TX
# $i94prt ; ISB ; PORT ISABEL, TX
# $i94prt ; POE ; PORT OF EL PASO, TX
# $i94prt ; PRE ; PRESIDIO, TX
# $i94prt ; PGR ; PROGRESO, TX
# $i94prt ; RIO ; RIO GRANDE CITY, TX
# $i94prt ; ROM ; ROMA, TX
# $i94prt ; SNA ; SAN ANTONIO, TX
# $i94prt ; SNN ; SANDERSON, TX
# $i94prt ; VIB ; VETERAN INTL BRIDGE, TX
# $i94prt ; YSL ; YSLETA, TX
# $i94prt ; CHA ; CHARLOTTE AMALIE, VI
# $i94prt ; CHR ; CHRISTIANSTED, VI
# $i94prt ; CRU ; CRUZ BAY, ST JOHN, VI
# $i94prt ; FRK ; FREDERIKSTED, VI
# $i94prt ; STT ; ST THOMAS, VI
# $i94prt ; LGU ; CACHE AIRPORT - LOGAN, UT
# $i94prt ; SLC ; SALT LAKE CITY, UT
# $i94prt ; CHO ; ALBEMARLE CHARLOTTESVILLE, VA
# $i94prt ; DAA ; DAVISON AAF - FAIRFAX CNTY, VA
# $i94prt ; HOP ; HOPEWELL, VA
# $i94prt ; HEF ; MANASSAS, VA #ARPT
# $i94prt ; NWN ; NEWPORT, VA
# $i94prt ; NOR ; NORFOLK, VA
# $i94prt ; RCM ; RICHMOND, VA
# $i94prt ; ABS ; ALBURG SPRINGS, VT
# $i94prt ; ABG ; ALBURG, VT
# $i94prt ; BEB ; BEEBE PLAIN, VT
# $i94prt ; BEE ; BEECHER FALLS, VT
# $i94prt ; BRG ; BURLINGTON, VT
# $i94prt ; CNA ; CANAAN, VT
# $i94prt ; DER ; DERBY LINE, VT (I-91)
# $i94prt ; DLV ; DERBY LINE, VT (RT. 5)
# $i94prt ; ERC ; EAST RICHFORD, VT
# $i94prt ; HIG ; HIGHGATE SPRINGS, VT
# $i94prt ; MOR ; MORSES LINE, VT
# $i94prt ; NPV ; NEWPORT, VT
# $i94prt ; NRT ; NORTH TROY, VT
# $i94prt ; NRN ; NORTON, VT
# $i94prt ; PIV ; PINNACLE ROAD, VT
# $i94prt ; RIF ; RICHFORT, VT
# $i94prt ; STA ; ST ALBANS, VT
# $i94prt ; SWB ; SWANTON, VT (BP - SECTOR HQ)
# $i94prt ; WBE ; WEST BERKSHIRE, VT
# $i94prt ; ABE ; ABERDEEN, WA
# $i94prt ; ANA ; ANACORTES, WA
# $i94prt ; BEL ; BELLINGHAM, WA
# $i94prt ; BLI ; BELLINGHAM, WASHINGTON #INTL
# $i94prt ; BLA ; BLAINE, WA
# $i94prt ; BWA ; BOUNDARY, WA
# $i94prt ; CUR ; CURLEW, WA (BPS)
# $i94prt ; DVL ; DANVILLE, WA
# $i94prt ; EVE ; EVERETT, WA
# $i94prt ; FER ; FERRY, WA
# $i94prt ; FRI ; FRIDAY HARBOR, WA
# $i94prt ; FWA ; FRONTIER, WA
# $i94prt ; KLM ; KALAMA, WA
# $i94prt ; LAU ; LAURIER, WA
# $i94prt ; LON ; LONGVIEW, WA
# $i94prt ; MET ; METALINE FALLS, WA
# $i94prt ; MWH ; MOSES LAKE GRANT COUNTY ARPT, WA
# $i94prt ; NEA ; NEAH BAY, WA
# $i94prt ; NIG ; NIGHTHAWK, WA
# $i94prt ; OLY ; OLYMPIA, WA
# $i94prt ; ORO ; OROVILLE, WA
# $i94prt ; PWB ; PASCO, WA
# $i94prt ; PIR ; POINT ROBERTS, WA
# $i94prt ; PNG ; PORT ANGELES, WA
# $i94prt ; PTO ; PORT TOWNSEND, WA
# $i94prt ; SEA ; SEATTLE, WA
# $i94prt ; SPO ; SPOKANE, WA
# $i94prt ; SUM ; SUMAS, WA
# $i94prt ; TAC ; TACOMA, WA
# $i94prt ; PSC ; TRI-CITIES - PASCO, WA
# $i94prt ; VAN ; VANCOUVER, WA
# $i94prt ; AGM ; ALGOMA, WI
# $i94prt ; BAY ; BAYFIELD, WI
# $i94prt ; GRB ; GREEN BAY, WI
# $i94prt ; MNW ; MANITOWOC, WI
# $i94prt ; MIL ; MILWAUKEE, WI
# $i94prt ; MSN ; TRUAX FIELD - DANE COUNTY, WI
# $i94prt ; CHS ; CHARLESTON, WV
# $i94prt ; CLK ; CLARKSBURG, WV
# $i94prt ; BLF ; MERCER COUNTY, WV
# $i94prt ; CSP ; CASPER, WY
# $i94prt ; XXX ; NOT REPORTED/UNKNOWN
# $i94prt ; 888 ; UNIDENTIFED AIR / SEAPORT
# $i94prt ; UNK ; UNKNOWN POE
# $i94prt ; CLG ; CALGARY, CANADA
# $i94prt ; EDA ; EDMONTON, CANADA
# $i94prt ; YHC ; HAKAI PASS, CANADA
# $i94prt ; HAL ; Halifax, NS, Canada
# $i94prt ; MON ; MONTREAL, CANADA
# $i94prt ; OTT ; OTTAWA, CANADA
# $i94prt ; YXE ; SASKATOON, CANADA
# $i94prt ; TOR ; TORONTO, CANADA
# $i94prt ; VCV ; VANCOUVER, CANADA
# $i94prt ; VIC ; VICTORIA, CANADA
# $i94prt ; WIN ; WINNIPEG, CANADA
# $i94prt ; AMS ; AMSTERDAM-SCHIPHOL, NETHERLANDS
# $i94prt ; ARB ; ARUBA, NETH ANTILLES
# $i94prt ; BAN ; BANKOK, THAILAND
# $i94prt ; BEI ; BEICA #ARPT, ETHIOPIA
# $i94prt ; PEK ; BEIJING CAPITAL INTL, PRC
# $i94prt ; BDA ; KINDLEY FIELD, BERMUDA
# $i94prt ; BOG ; BOGOTA, EL DORADO #ARPT, COLOMBIA
# $i94prt ; EZE ; BUENOS AIRES, MINISTRO PIST, ARGENTINA
# $i94prt ; CUN ; CANCUN, MEXICO
# $i94prt ; CRQ ; CARAVELAS, BA #ARPT, BRAZIL
# $i94prt ; MVD ; CARRASCO, URUGUAY
# $i94prt ; DUB ; DUBLIN, IRELAND
# $i94prt ; FOU ; FOUGAMOU #ARPT, GABON
# $i94prt ; FBA ; FREEPORT, BAHAMAS
# $i94prt ; MTY ; GEN M. ESCOBEDO, Monterrey, MX
# $i94prt ; HMO ; GEN PESQUEIRA GARCIA, MX
# $i94prt ; GCM ; GRAND CAYMAN, CAYMAN ISLAND
# $i94prt ; GDL ; GUADALAJARA, MIGUEL HIDAL, MX
# $i94prt ; HAM ; HAMILTON, BERMUDA
# $i94prt ; ICN ; INCHON, SEOUL KOREA
# $i94prt ; IWA ; INVALID - IWAKUNI, JAPAN
# $i94prt ; CND ; KOGALNICEANU, ROMANIA
# $i94prt ; LAH ; LABUHA ARPT, INDONESIA
# $i94prt ; DUR ; LOUIS BOTHA, SOUTH AFRICA
# $i94prt ; MAL ; MANGOLE ARPT, INDONESIA
# $i94prt ; MDE ; MEDELLIN, COLOMBIA
# $i94prt ; MEX ; JUAREZ INTL, MEXICO CITY, MX
# $i94prt ; LHR ; MIDDLESEX, ENGLAND
# $i94prt ; NBO ; NAIROBI, KENYA
# $i94prt ; NAS ; NASSAU, BAHAMAS
# $i94prt ; NCA ; NORTH CAICOS, TURK & CAIMAN
# $i94prt ; PTY ; OMAR TORRIJOS, PANAMA
# $i94prt ; SPV ; PAPUA, NEW GUINEA
# $i94prt ; UIO ; QUITO (MARISCAL SUCR), ECUADOR
# $i94prt ; RIT ; ROME, ITALY
# $i94prt ; SNO ; SAKON NAKHON #ARPT, THAILAND
# $i94prt ; SLP ; SAN LUIS POTOSI #ARPT, MEXICO
# $i94prt ; SAN ; SAN SALVADOR, EL SALVADOR
# $i94prt ; SRO ; SANTANA RAMOS #ARPT, COLOMBIA
# $i94prt ; GRU ; GUARULHOS INTL, SAO PAULO, BRAZIL
# $i94prt ; SHA ; SHANNON, IRELAND
# $i94prt ; HIL ; SHILLAVO, ETHIOPIA
# $i94prt ; TOK ; TOROKINA #ARPT, PAPUA, NEW GUINEA
# $i94prt ; VER ; VERACRUZ, MEXICO
# $i94prt ; LGW ; WEST SUSSEX, ENGLAND
# $i94prt ; ZZZ ; MEXICO Land (Banco de Mexico)
# $i94prt ; CHN ; No PORT Code (CHN)
# $i94prt ; CNC ; CANNON CORNERS, NY
# $i94prt ; MAA ; Abu Dhabi
# $i94prt ; AG0 ; MAGNOLIA, AR
# $i94prt ; BHM ; BAR HARBOR, ME
# $i94prt ; BHX ; BIRMINGHAM, AL
# $i94prt ; CAK ; AKRON, OH
# $i94prt ; FOK ; SUFFOLK COUNTY, NY
# $i94prt ; LND ; LANDER, WY
# $i94prt ; MAR ; MARFA, TX
# $i94prt ; MLI ; MOLINE, IL
# $i94prt ; RIV ; RIVERSIDE, CA
# $i94prt ; RME ; ROME, NY
# $i94prt ; VNY ; VAN NUYS, CA
# $i94prt ; YUM ; YUMA, AZ
# $i94prt ; FRG ; Collapsed (FOK) 06/15
# $i94prt ; HRL ; Collapsed (HLG) 06/15
# $i94prt ; ISP ; Collapsed (FOK) 06/15
# $i94prt ; JSJ ; Collapsed (SAJ) 06/15
# $i94prt ; BUS ; Collapsed (BUF) 06/15
# $i94prt ; IAG ; Collapsed (NIA) 06/15
# $i94prt ; PHN ; Collapsed (PHU) 06/15
# $i94prt ; STN ; Collapsed (STR) 06/15
# $i94prt ; VMB ; Collapsed (VNB) 06/15
# $i94prt ; T01 ; Collapsed (SEA) 06/15
# $i94prt ; PHF ; No PORT Code (PHF)
# $i94prt ; DRV ; No PORT Code (DRV)
# $i94prt ; FTB ; No PORT Code (FTB)
# $i94prt ; GAC ; No PORT Code (GAC)
# $i94prt ; GMT ; No PORT Code (GMT)
# $i94prt ; JFA ; No PORT Code (JFA)
# $i94prt ; JMZ ; No PORT Code (JMZ)
# $i94prt ; NC8 ; No PORT Code (NC8)
# $i94prt ; NYL ; No PORT Code (NYL)
# $i94prt ; OAI ; No PORT Code (OAI)
# $i94prt ; PCW ; No PORT Code (PCW)
# $i94prt ; WA5 ; No PORT Code (WAS)
# $i94prt ; WTR ; No PORT Code (WTR)
# $i94prt ; X96 ; No PORT Code (X96)
# $i94prt ; XNA ; No PORT Code (XNA)
# $i94prt ; YGF ; No PORT Code (YGF)
# $i94prt ; 5T6 ; No PORT Code (5T6)
# $i94prt ; 060 ; No PORT Code (60)
# $i94prt ; SP0 ; No PORT Code (SP0)
# $i94prt ; W55 ; No PORT Code (W55)
# $i94prt ; X44 ; No PORT Code (X44)
# $i94prt ; AUH ; No PORT Code (AUH)
# $i94prt ; RYY ; No PORT Code (RYY)
# $i94prt ; SUS ; No PORT Code (SUS)
# $i94prt ; 74S ; No PORT Code (74S)
# $i94prt ; ATW ; No PORT Code (ATW)
# $i94prt ; CPX ; No PORT Code (CPX)
# $i94prt ; MTH ; No PORT Code (MTH)
# $i94prt ; PFN ; No PORT Code (PFN)
# $i94prt ; SCH ; No PORT Code (SCH)
# $i94prt ; ASI ; No PORT Code (ASI)
# $i94prt ; BKF ; No PORT Code (BKF)
# $i94prt ; DAY ; No PORT Code (DAY)
# $i94prt ; Y62 ; No PORT Code (Y62)
# $i94prt ; AG ; No PORT Code (AG)
# $i94prt ; BCM ; No PORT Code (BCM)
# $i94prt ; DEC ; No PORT Code (DEC)
# $i94prt ; PLB ; No PORT Code (PLB)
# $i94prt ; CXO ; No PORT Code (CXO)
# $i94prt ; JBQ ; No PORT Code (JBQ)
# $i94prt ; JIG ; No PORT Code (JIG)
# $i94prt ; OGS ; No PORT Code (OGS)
# $i94prt ; TIW ; No PORT Code (TIW)
# $i94prt ; OTS ; No PORT Code (OTS)
# $i94prt ; AMT ; No PORT Code (AMT)
# $i94prt ; EGE ; No PORT Code (EGE)
# $i94prt ; GPI ; No PORT Code (GPI)
# $i94prt ; NGL ; No PORT Code (NGL)
# $i94prt ; OLM ; No PORT Code (OLM)
# $i94prt ; .GA ; No PORT Code (.GA)
# $i94prt ; CLX ; No PORT Code (CLX)
# $i94prt ; CP  ; No PORT Code (CP)
# $i94prt ; FSC ; No PORT Code (FSC)
# $i94prt ; NK ; No PORT Code (NK)
# $i94prt ; ADU ; No PORT Code (ADU)
# $i94prt ; AKT ; No PORT Code (AKT)
# $i94prt ; LIT ; No PORT Code (LIT)
# $i94prt ; A2A ; No PORT Code (A2A)
# $i94prt ; OSN ; No PORT Code (OSN)
# i94mode ; 1 ; Air
# i94mode ; 2 ; Sea
# i94mode ; 3 ; Land
# i94mode ; 9 ; Not reported' ;
# i94addr ; AL ; ALABAMA
# i94addr ; AK ; ALASKA
# i94addr ; AZ ; ARIZONA
# i94addr ; AR ; ARKANSAS
# i94addr ; CA ; CALIFORNIA
# i94addr ; CO ; COLORADO
# i94addr ; CT ; CONNECTICUT
# i94addr ; DE ; DELAWARE
# i94addr ; DC ; DIST. OF COLUMBIA
# i94addr ; FL ; FLORIDA
# i94addr ; GA ; GEORGIA
# i94addr ; GU ; GUAM
# i94addr ; HI ; HAWAII
# i94addr ; ID ; IDAHO
# i94addr ; IL ; ILLINOIS
# i94addr ; IN ; INDIANA
# i94addr ; IA ; IOWA
# i94addr ; KS ; KANSAS
# i94addr ; KY ; KENTUCKY
# i94addr ; LA ; LOUISIANA
# i94addr ; ME ; MAINE
# i94addr ; MD ; MARYLAND
# i94addr ; MA ; MASSACHUSETTS
# i94addr ; MI ; MICHIGAN
# i94addr ; MN ; MINNESOTA
# i94addr ; MS ; MISSISSIPPI
# i94addr ; MO ; MISSOURI
# i94addr ; MT ; MONTANA
# i94addr ; NC ; N. CAROLINA
# i94addr ; ND ; N. DAKOTA
# i94addr ; NE ; NEBRASKA
# i94addr ; NV ; NEVADA
# i94addr ; NH ; NEW HAMPSHIRE
# i94addr ; NJ ; NEW JERSEY
# i94addr ; NM ; NEW MEXICO
# i94addr ; NY ; NEW YORK
# i94addr ; OH ; OHIO
# i94addr ; OK ; OKLAHOMA
# i94addr ; OR ; OREGON
# i94addr ; PA ; PENNSYLVANIA
# i94addr ; PR ; PUERTO RICO
# i94addr ; RI ; RHODE ISLAND
# i94addr ; SC ; S. CAROLINA
# i94addr ; SD ; S. DAKOTA
# i94addr ; TN ; TENNESSEE
# i94addr ; TX ; TEXAS
# i94addr ; UT ; UTAH
# i94addr ; VT ; VERMONT
# i94addr ; VI ; VIRGIN ISLANDS
# i94addr ; VA ; VIRGINIA
# i94addr ; WV ; W. VIRGINIA
# i94addr ; WA ; WASHINGTON
# i94addr ; WI ; WISCONSON
# i94addr ; WY ; WYOMING
# i94addr ; 99 ; All Other Codes' ;

# %%
result_dict
# Out:
# {'i94yr': '4 digit year',
#  'i94mon': 'Numeric month',
#  'i94cit': 'This format shows all the valid and invalid codes for processing',
#  'i94res': 'This format shows all the valid and invalid codes for processing',
#  ('i94cnty',
#   '582'): 'MEXICO Air Sea, and Not Reported (I-94, no land arrivals)',
#  ('i94cnty', '236'): 'AFGHANISTAN',
#  ('i94cnty', '101'): 'ALBANIA',
#  ('i94cnty', '316'): 'ALGERIA',
#  ('i94cnty', '102'): 'ANDORRA',
#  ('i94cnty', '324'): 'ANGOLA',
#  ('i94cnty', '529'): 'ANGUILLA',
#  ('i94cnty', '518'): 'ANTIGUA-BARBUDA',
#  ('i94cnty', '687'): 'ARGENTINA ',
#  ('i94cnty', '151'): 'ARMENIA',
#  ('i94cnty', '532'): 'ARUBA',
#  ('i94cnty', '438'): 'AUSTRALIA',
#  ('i94cnty', '103'): 'AUSTRIA',
#  ('i94cnty', '152'): 'AZERBAIJAN',
#  ('i94cnty', '512'): 'BAHAMAS',
#  ('i94cnty', '298'): 'BAHRAIN',
#  ('i94cnty', '274'): 'BANGLADESH',
#  ('i94cnty', '513'): 'BARBADOS',
#  ('i94cnty', '104'): 'BELGIUM',
#  ('i94cnty', '581'): 'BELIZE',
#  ('i94cnty', '386'): 'BENIN',
#  ('i94cnty', '509'): 'BERMUDA',
#  ('i94cnty', '153'): 'BELARUS',
#  ('i94cnty', '242'): 'BHUTAN',
#  ('i94cnty', '688'): 'BOLIVIA',
#  ('i94cnty', '717'): 'BONAIRE, ST EUSTATIUS, SABA',
#  ('i94cnty', '164'): 'BOSNIA-HERZEGOVINA',
#  ('i94cnty', '336'): 'BOTSWANA',
#  ('i94cnty', '689'): 'BRAZIL',
#  ('i94cnty', '525'): 'BRITISH VIRGIN ISLANDS',
#  ('i94cnty', '217'): 'BRUNEI',
#  ('i94cnty', '105'): 'BULGARIA',
#  ('i94cnty', '393'): 'BURKINA FASO',
#  ('i94cnty', '243'): 'BURMA',
#  ('i94cnty', '375'): 'BURUNDI',
#  ('i94cnty', '310'): 'CAMEROON',
#  ('i94cnty', '326'): 'CAPE VERDE',
#  ('i94cnty', '526'): 'CAYMAN ISLANDS',
#  ('i94cnty', '383'): 'CENTRAL AFRICAN REPUBLIC',
#  ('i94cnty', '384'): 'CHAD',
#  ('i94cnty', '690'): 'CHILE',
#  ('i94cnty', '245'): 'CHINA, PRC',
#  ('i94cnty', '721'): 'CURACAO',
#  ('i94cnty', '270'): 'CHRISTMAS ISLAND',
#  ('i94cnty', '271'): 'COCOS ISLANDS',
#  ('i94cnty', '691'): 'COLOMBIA',
#  ('i94cnty', '317'): 'COMOROS',
#  ('i94cnty', '385'): 'CONGO',
#  ('i94cnty', '467'): 'COOK ISLANDS',
#  ('i94cnty', '575'): 'COSTA RICA',
#  ('i94cnty', '165'): 'CROATIA',
#  ('i94cnty', '584'): 'CUBA',
#  ('i94cnty', '218'): 'CYPRUS',
#  ('i94cnty', '140'): 'CZECH REPUBLIC',
#  ('i94cnty', '723'): 'FAROE ISLANDS (PART OF DENMARK)',
#  ('i94cnty', '108'): 'DENMARK',
#  ('i94cnty', '322'): 'DJIBOUTI',
#  ('i94cnty', '519'): 'DOMINICA',
#  ('i94cnty', '585'): 'DOMINICAN REPUBLIC',
#  ('i94cnty', '240'): 'EAST TIMOR',
#  ('i94cnty', '692'): 'ECUADOR',
#  ('i94cnty', '368'): 'EGYPT',
#  ('i94cnty', '576'): 'EL SALVADOR',
#  ('i94cnty', '399'): 'EQUATORIAL GUINEA',
#  ('i94cnty', '372'): 'ERITREA',
#  ('i94cnty', '109'): 'ESTONIA',
#  ('i94cnty', '369'): 'ETHIOPIA',
#  ('i94cnty', '604'): 'FALKLAND ISLANDS',
#  ('i94cnty', '413'): 'FIJI',
#  ('i94cnty', '110'): 'FINLAND',
#  ('i94cnty', '111'): 'FRANCE',
#  ('i94cnty', '601'): 'FRENCH GUIANA',
#  ('i94cnty', '411'): 'FRENCH POLYNESIA',
#  ('i94cnty', '387'): 'GABON',
#  ('i94cnty', '338'): 'GAMBIA',
#  ('i94cnty', '758'): 'GAZA STRIP',
#  ('i94cnty', '154'): 'GEORGIA',
#  ('i94cnty', '112'): 'GERMANY',
#  ('i94cnty', '339'): 'GHANA',
#  ('i94cnty', '143'): 'GIBRALTAR',
#  ('i94cnty', '113'): 'GREECE',
#  ('i94cnty', '520'): 'GRENADA',
#  ('i94cnty', '507'): 'GUADELOUPE',
#  ('i94cnty', '577'): 'GUATEMALA',
#  ('i94cnty', '382'): 'GUINEA',
#  ('i94cnty', '327'): 'GUINEA-BISSAU',
#  ('i94cnty', '603'): 'GUYANA',
#  ('i94cnty', '586'): 'HAITI',
#  ('i94cnty', '726'): 'HEARD AND MCDONALD IS.',
#  ('i94cnty', '149'): 'HOLY SEE/VATICAN',
#  ('i94cnty', '528'): 'HONDURAS',
#  ('i94cnty', '206'): 'HONG KONG',
#  ('i94cnty', '114'): 'HUNGARY',
#  ('i94cnty', '115'): 'ICELAND',
#  ('i94cnty', '213'): 'INDIA',
#  ('i94cnty', '759'): 'INDIAN OCEAN AREAS (FRENCH)',
#  ('i94cnty', '729'): 'INDIAN OCEAN TERRITORY',
#  ('i94cnty', '204'): 'INDONESIA',
#  ('i94cnty', '249'): 'IRAN',
#  ('i94cnty', '250'): 'IRAQ',
#  ('i94cnty', '116'): 'IRELAND',
#  ('i94cnty', '251'): 'ISRAEL',
#  ('i94cnty', '117'): 'ITALY',
#  ('i94cnty', '388'): 'IVORY COAST',
#  ('i94cnty', '514'): 'JAMAICA',
#  ('i94cnty', '209'): 'JAPAN',
#  ('i94cnty', '253'): 'JORDAN',
#  ('i94cnty', '201'): 'KAMPUCHEA',
#  ('i94cnty', '155'): 'KAZAKHSTAN',
#  ('i94cnty', '340'): 'KENYA',
#  ('i94cnty', '414'): 'KIRIBATI',
#  ('i94cnty', '732'): 'KOSOVO',
#  ('i94cnty', '272'): 'KUWAIT',
#  ('i94cnty', '156'): 'KYRGYZSTAN',
#  ('i94cnty', '203'): 'LAOS',
#  ('i94cnty', '118'): 'LATVIA',
#  ('i94cnty', '255'): 'LEBANON',
#  ('i94cnty', '335'): 'LESOTHO',
#  ('i94cnty', '370'): 'LIBERIA',
#  ('i94cnty', '381'): 'LIBYA',
#  ('i94cnty', '119'): 'LIECHTENSTEIN',
#  ('i94cnty', '120'): 'LITHUANIA',
#  ('i94cnty', '121'): 'LUXEMBOURG',
#  ('i94cnty', '214'): 'MACAU',
#  ('i94cnty', '167'): 'MACEDONIA',
#  ('i94cnty', '320'): 'MADAGASCAR',
#  ('i94cnty', '345'): 'MALAWI',
#  ('i94cnty', '273'): 'MALAYSIA',
#  ('i94cnty', '220'): 'MALDIVES',
#  ('i94cnty', '392'): 'MALI',
#  ('i94cnty', '145'): 'MALTA',
#  ('i94cnty', '472'): 'MARSHALL ISLANDS',
#  ('i94cnty', '511'): 'MARTINIQUE',
#  ('i94cnty', '389'): 'MAURITANIA',
#  ('i94cnty', '342'): 'MAURITIUS',
#  ('i94cnty', '760'): 'MAYOTTE (AFRICA - FRENCH)',
#  ('i94cnty', '473'): 'MICRONESIA, FED. STATES OF',
#  ('i94cnty', '157'): 'MOLDOVA',
#  ('i94cnty', '122'): 'MONACO',
#  ('i94cnty', '299'): 'MONGOLIA',
#  ('i94cnty', '735'): 'MONTENEGRO',
#  ('i94cnty', '521'): 'MONTSERRAT',
#  ('i94cnty', '332'): 'MOROCCO',
#  ('i94cnty', '329'): 'MOZAMBIQUE',
#  ('i94cnty', '371'): 'NAMIBIA',
#  ('i94cnty', '440'): 'NAURU',
#  ('i94cnty', '257'): 'NEPAL',
#  ('i94cnty', '123'): 'NETHERLANDS',
#  ('i94cnty', '508'): 'NETHERLANDS ANTILLES',
#  ('i94cnty', '409'): 'NEW CALEDONIA',
#  ('i94cnty', '464'): 'NEW ZEALAND',
#  ('i94cnty', '579'): 'NICARAGUA',
#  ('i94cnty', '390'): 'NIGER',
#  ('i94cnty', '343'): 'NIGERIA',
#  ('i94cnty', '470'): 'NIUE',
#  ('i94cnty', '275'): 'NORTH KOREA',
#  ('i94cnty', '124'): 'NORWAY',
#  ('i94cnty', '256'): 'OMAN',
#  ('i94cnty', '258'): 'PAKISTAN',
#  ('i94cnty', '474'): 'PALAU',
#  ('i94cnty', '743'): 'PALESTINE',
#  ('i94cnty', '504'): 'PANAMA',
#  ('i94cnty', '441'): 'PAPUA NEW GUINEA',
#  ('i94cnty', '693'): 'PARAGUAY',
#  ('i94cnty', '694'): 'PERU',
#  ('i94cnty', '260'): 'PHILIPPINES',
#  ('i94cnty', '416'): 'PITCAIRN ISLANDS',
#  ('i94cnty', '107'): 'POLAND',
#  ('i94cnty', '126'): 'PORTUGAL',
#  ('i94cnty', '297'): 'QATAR',
#  ('i94cnty', '748'): 'REPUBLIC OF SOUTH SUDAN',
#  ('i94cnty', '321'): 'REUNION',
#  ('i94cnty', '127'): 'ROMANIA',
#  ('i94cnty', '158'): 'RUSSIA',
#  ('i94cnty', '376'): 'RWANDA',
#  ('i94cnty', '128'): 'SAN MARINO',
#  ('i94cnty', '330'): 'SAO TOME AND PRINCIPE',
#  ('i94cnty', '261'): 'SAUDI ARABIA',
#  ('i94cnty', '391'): 'SENEGAL',
#  ('i94cnty', '142'): 'SERBIA AND MONTENEGRO',
#  ('i94cnty', '745'): 'SERBIA',
#  ('i94cnty', '347'): 'SEYCHELLES',
#  ('i94cnty', '348'): 'SIERRA LEONE',
#  ('i94cnty', '207'): 'SINGAPORE',
#  ('i94cnty', '141'): 'SLOVAKIA',
#  ('i94cnty', '166'): 'SLOVENIA',
#  ('i94cnty', '412'): 'SOLOMON ISLANDS',
#  ('i94cnty', '397'): 'SOMALIA',
#  ('i94cnty', '373'): 'SOUTH AFRICA',
#  ('i94cnty', '276'): 'SOUTH KOREA',
#  ('i94cnty', '129'): 'SPAIN',
#  ('i94cnty', '244'): 'SRI LANKA',
#  ('i94cnty', '346'): 'ST. HELENA',
#  ('i94cnty', '522'): 'ST. KITTS-NEVIS',
#  ('i94cnty', '523'): 'ST. LUCIA',
#  ('i94cnty', '502'): 'ST. PIERRE AND MIQUELON',
#  ('i94cnty', '524'): 'ST. VINCENT-GRENADINES',
#  ('i94cnty', '716'): 'SAINT BARTHELEMY',
#  ('i94cnty', '736'): 'SAINT MARTIN',
#  ('i94cnty', '749'): 'SAINT MAARTEN',
#  ('i94cnty', '350'): 'SUDAN',
#  ('i94cnty', '602'): 'SURINAME',
#  ('i94cnty', '351'): 'SWAZILAND',
#  ('i94cnty', '130'): 'SWEDEN',
#  ('i94cnty', '131'): 'SWITZERLAND',
#  ('i94cnty', '262'): 'SYRIA',
#  ('i94cnty', '268'): 'TAIWAN',
#  ('i94cnty', '159'): 'TAJIKISTAN',
#  ('i94cnty', '353'): 'TANZANIA',
#  ('i94cnty', '263'): 'THAILAND',
#  ('i94cnty', '304'): 'TOGO',
#  ('i94cnty', '417'): 'TONGA',
#  ('i94cnty', '516'): 'TRINIDAD AND TOBAGO',
#  ('i94cnty', '323'): 'TUNISIA',
#  ('i94cnty', '264'): 'TURKEY',
#  ('i94cnty', '161'): 'TURKMENISTAN',
#  ('i94cnty', '527'): 'TURKS AND CAICOS ISLANDS',
#  ('i94cnty', '420'): 'TUVALU',
#  ('i94cnty', '352'): 'UGANDA',
#  ('i94cnty', '162'): 'UKRAINE',
#  ('i94cnty', '296'): 'UNITED ARAB EMIRATES',
#  ('i94cnty', '135'): 'UNITED KINGDOM',
#  ('i94cnty', '695'): 'URUGUAY',
#  ('i94cnty', '163'): 'UZBEKISTAN',
#  ('i94cnty', '410'): 'VANUATU',
#  ('i94cnty', '696'): 'VENEZUELA',
#  ('i94cnty', '266'): 'VIETNAM',
#  ('i94cnty', '469'): 'WALLIS AND FUTUNA ISLANDS',
#  ('i94cnty', '757'): 'WEST INDIES (FRENCH)',
#  ('i94cnty', '333'): 'WESTERN SAHARA',
#  ('i94cnty', '465'): 'WESTERN SAMOA',
#  ('i94cnty', '216'): 'YEMEN',
#  ('i94cnty', '139'): 'YUGOSLAVIA',
#  ('i94cnty', '301'): 'ZAIRE',
#  ('i94cnty', '344'): 'ZAMBIA',
#  ('i94cnty', '315'): 'ZIMBABWE',
#  ('i94cnty', '403'): 'INVALID: AMERICAN SAMOA',
#  ('i94cnty', '712'): 'INVALID: ANTARCTICA',
#  ('i94cnty', '700'): 'INVALID: BORN ON BOARD SHIP',
#  ('i94cnty', '719'): 'INVALID: BOUVET ISLAND (ANTARCTICA/NORWAY TERR.)',
#  ('i94cnty', '574'): 'INVALID: CANADA',
#  ('i94cnty', '720'): 'INVALID: CANTON AND ENDERBURY ISLS',
#  ('i94cnty', '106'): 'INVALID: CZECHOSLOVAKIA',
#  ('i94cnty', '739'): 'INVALID: DRONNING MAUD LAND (ANTARCTICA-NORWAY)',
#  ('i94cnty', '394'): 'INVALID: FRENCH SOUTHERN AND ANTARCTIC',
#  ('i94cnty', '501'): 'INVALID: GREENLAND',
#  ('i94cnty', '404'): 'INVALID: GUAM',
#  ('i94cnty', '730'): 'INVALID: INTERNATIONAL WATERS',
#  ('i94cnty', '731'): 'INVALID: JOHNSON ISLAND',
#  ('i94cnty', '471'): 'INVALID: MARIANA ISLANDS, NORTHERN',
#  ('i94cnty', '737'): 'INVALID: MIDWAY ISLANDS',
#  ('i94cnty', '753'): 'INVALID: MINOR OUTLYING ISLANDS - USA',
#  ('i94cnty', '740'): 'INVALID: NEUTRAL ZONE (S. ARABIA/IRAQ)',
#  ('i94cnty', '710'): 'INVALID: NON-QUOTA IMMIGRANT',
#  ('i94cnty', '505'): 'INVALID: PUERTO RICO',
#  ('i94cnty', '0'): 'INVALID: STATELESS',
#  ('i94cnty', '705'): 'INVALID: STATELESS',
#  ('i94cnty', '583'): 'INVALID: UNITED STATES',
#  ('i94cnty', '407'): 'INVALID: UNITED STATES',
#  ('i94cnty', '999'): 'INVALID: UNKNOWN',
#  ('i94cnty', '239'): 'INVALID: UNKNOWN COUNTRY',
#  ('i94cnty', '134'): 'INVALID: USSR',
#  ('i94cnty', '506'): 'INVALID: U.S. VIRGIN ISLANDS',
#  ('i94cnty', '755'): 'INVALID: WAKE ISLAND',
#  ('i94cnty', '311'): 'Collapsed Tanzania (should not show)',
#  ('i94cnty', '741'): 'Collapsed Curacao (should not show)',
#  ('i94cnty', '54'): 'No Country Code (54)',
#  ('i94cnty', '100'): 'No Country Code (100)',
#  ('i94cnty', '187'): 'No Country Code (187)',
#  ('i94cnty', '190'): 'No Country Code (190)',
#  ('i94cnty', '200'): 'No Country Code (200)',
#  ('i94cnty', '219'): 'No Country Code (219)',
#  ('i94cnty', '238'): 'No Country Code (238)',
#  ('i94cnty', '277'): 'No Country Code (277)',
#  ('i94cnty', '293'): 'No Country Code (293)',
#  ('i94cnty', '300'): 'No Country Code (300)',
#  ('i94cnty', '319'): 'No Country Code (319)',
#  ('i94cnty', '365'): 'No Country Code (365)',
#  ('i94cnty', '395'): 'No Country Code (395)',
#  ('i94cnty', '400'): 'No Country Code (400)',
#  ('i94cnty', '485'): 'No Country Code (485)',
#  ('i94cnty', '503'): 'No Country Code (503)',
#  ('i94cnty', '589'): 'No Country Code (589)',
#  ('i94cnty', '592'): 'No Country Code (592)',
#  ('i94cnty', '791'): 'No Country Code (791)',
#  ('i94cnty', '849'): 'No Country Code (849)',
#  ('i94cnty', '914'): 'No Country Code (914)',
#  ('i94cnty', '944'): 'No Country Code (944)',
#  ('i94cnty', '996'): "No Country Code (996)' ;",
#  'i94port': 'This format shows all the valid and invalid codes for processing',
#  ('$i94prt', 'ALC'): 'ALCAN, AK             ',
#  ('$i94prt', 'ANC'): 'ANCHORAGE, AK         ',
#  ('$i94prt', 'BAR'): 'BAKER AAF - BAKER ISLAND, AK',
#  ('$i94prt', 'DAC'): 'DALTONS CACHE, AK     ',
#  ('$i94prt', 'PIZ'): 'DEW STATION PT LAY DEW, AK',
#  ('$i94prt', 'DTH'): 'DUTCH HARBOR, AK      ',
#  ('$i94prt', 'EGL'): 'EAGLE, AK             ',
#  ('$i94prt', 'FRB'): 'FAIRBANKS, AK         ',
#  ('$i94prt', 'HOM'): 'HOMER, AK             ',
#  ('$i94prt', 'HYD'): 'HYDER, AK             ',
#  ('$i94prt', 'JUN'): 'JUNEAU, AK            ',
#  ('$i94prt', '5KE'): 'KETCHIKAN, AK',
#  ('$i94prt', 'KET'): 'KETCHIKAN, AK         ',
#  ('$i94prt', 'MOS'): 'MOSES POINT INTERMEDIATE, AK',
#  ('$i94prt', 'NIK'): 'NIKISKI, AK           ',
#  ('$i94prt', 'NOM'): 'NOM, AK               ',
#  ('$i94prt', 'PKC'): 'POKER CREEK, AK       ',
#  ('$i94prt', 'ORI'): 'PORT LIONS SPB, AK',
#  ('$i94prt', 'SKA'): 'SKAGWAY, AK           ',
#  ('$i94prt', 'SNP'): 'ST. PAUL ISLAND, AK',
#  ('$i94prt', 'TKI'): 'TOKEEN, AK',
#  ('$i94prt', 'WRA'): 'WRANGELL, AK          ',
#  ('$i94prt', 'HSV'): 'MADISON COUNTY - HUNTSVILLE, AL',
#  ('$i94prt', 'MOB'): 'MOBILE, AL            ',
#  ('$i94prt', 'LIA'): 'LITTLE ROCK, AR (BPS)',
#  ('$i94prt', 'ROG'): 'ROGERS ARPT, AR',
#  ('$i94prt', 'DOU'): 'DOUGLAS, AZ           ',
#  ('$i94prt', 'LUK'): 'LUKEVILLE, AZ         ',
#  ('$i94prt', 'MAP'): 'MARIPOSA AZ           ',
#  ('$i94prt', 'NAC'): 'NACO, AZ              ',
#  ('$i94prt', 'NOG'): 'NOGALES, AZ           ',
#  ('$i94prt', 'PHO'): 'PHOENIX, AZ           ',
#  ('$i94prt', 'POR'): 'PORTAL, AZ',
#  ('$i94prt', 'SLU'): 'SAN LUIS, AZ          ',
#  ('$i94prt', 'SAS'): 'SASABE, AZ            ',
#  ('$i94prt', 'TUC'): 'TUCSON, AZ            ',
#  ('$i94prt', 'YUI'): 'YUMA, AZ              ',
#  ('$i94prt', 'AND'): 'ANDRADE, CA           ',
#  ('$i94prt', 'BUR'): 'BURBANK, CA',
#  ('$i94prt', 'CAL'): 'CALEXICO, CA          ',
#  ('$i94prt', 'CAO'): 'CAMPO, CA             ',
#  ('$i94prt', 'FRE'): 'FRESNO, CA            ',
#  ('$i94prt', 'ICP'): 'IMPERIAL COUNTY, CA   ',
#  ('$i94prt', 'LNB'): 'LONG BEACH, CA         ',
#  ('$i94prt', 'LOS'): 'LOS ANGELES, CA       ',
#  ('$i94prt', 'BFL'): 'MEADOWS FIELD - BAKERSFIELD, CA',
#  ('$i94prt', 'OAK'): 'OAKLAND, CA ',
#  ('$i94prt', 'ONT'): 'ONTARIO, CA',
#  ('$i94prt', 'OTM'): 'OTAY MESA, CA          ',
#  ('$i94prt', 'BLT'): 'PACIFIC, HWY. STATION, CA ',
#  ('$i94prt', 'PSP'): 'PALM SPRINGS, CA',
#  ('$i94prt', 'SAC'): 'SACRAMENTO, CA        ',
#  ('$i94prt', 'SLS'): 'SALINAS, CA (BPS)',
#  ('$i94prt', 'SDP'): 'SAN DIEGO, CA',
#  ('$i94prt', 'SFR'): 'SAN FRANCISCO, CA     ',
#  ('$i94prt', 'SNJ'): 'SAN JOSE, CA          ',
#  ('$i94prt', 'SLO'): 'SAN LUIS OBISPO, CA   ',
#  ('$i94prt', 'SLI'): 'SAN LUIS OBISPO, CA (BPS)',
#  ('$i94prt', 'SPC'): 'SAN PEDRO, CA         ',
#  ('$i94prt', 'SYS'): 'SAN YSIDRO, CA        ',
#  ('$i94prt', 'SAA'): 'SANTA ANA, CA         ',
#  ('$i94prt', 'STO'): 'STOCKTON, CA (BPS)',
#  ('$i94prt', 'TEC'): 'TECATE, CA            ',
#  ('$i94prt', 'TRV'): 'TRAVIS-AFB, CA        ',
#  ('$i94prt', 'APA'): 'ARAPAHOE COUNTY, CO',
#  ('$i94prt', 'ASE'): 'ASPEN, CO #ARPT',
#  ('$i94prt', 'COS'): 'COLORADO SPRINGS, CO',
#  ('$i94prt', 'DEN'): 'DENVER, CO            ',
#  ('$i94prt', 'DRO'): 'LA PLATA - DURANGO, CO',
#  ('$i94prt', 'BDL'): 'BRADLEY INTERNATIONAL, CT',
#  ('$i94prt', 'BGC'): 'BRIDGEPORT, CT        ',
#  ('$i94prt', 'GRT'): 'GROTON, CT            ',
#  ('$i94prt', 'HAR'): 'HARTFORD, CT          ',
#  ('$i94prt', 'NWH'): 'NEW HAVEN, CT         ',
#  ('$i94prt', 'NWL'): 'NEW LONDON, CT        ',
#  ('$i94prt', 'TST'): 'NEWINGTON DATA CENTER TEST, CT',
#  ('$i94prt', 'WAS'): 'WASHINGTON DC         ',
#  ('$i94prt', 'DOV'): 'DOVER AFB, DE',
#  ('$i94prt', 'DVD'): 'DOVER-AFB, DE         ',
#  ('$i94prt', 'WLL'): 'WILMINGTON, DE        ',
#  ('$i94prt', 'BOC'): 'BOCAGRANDE, FL        ',
#  ('$i94prt', 'SRQ'): 'BRADENTON - SARASOTA, FL',
#  ('$i94prt', 'CAN'): 'CAPE CANAVERAL, FL    ',
#  ('$i94prt', 'DAB'): 'DAYTONA BEACH INTERNATIONAL, FL',
#  ('$i94prt', 'FRN'): 'FERNANDINA, FL        ',
#  ('$i94prt', 'FTL'): 'FORT LAUDERDALE, FL   ',
#  ('$i94prt', 'FMY'): 'FORT MYERS, FL        ',
#  ('$i94prt', 'FPF'): 'FORT PIERCE, FL       ',
#  ('$i94prt', 'HUR'): 'HURLBURT FIELD, FL',
#  ('$i94prt', 'GNV'): 'J R ALISON MUNI - GAINESVILLE, FL',
#  ('$i94prt', 'JAC'): 'JACKSONVILLE, FL      ',
#  ('$i94prt', 'KEY'): 'KEY WEST, FL          ',
#  ('$i94prt', 'LEE'): 'LEESBURG MUNICIPAL AIRPORT, FL',
#  ('$i94prt', 'MLB'): 'MELBOURNE, FL',
#  ('$i94prt', 'MIA'): 'MIAMI, FL             ',
#  ('$i94prt', 'APF'): 'NAPLES, FL #ARPT',
#  ('$i94prt', 'OPF'): 'OPA LOCKA, FL',
#  ('$i94prt', 'ORL'): 'ORLANDO, FL           ',
#  ('$i94prt', 'PAN'): 'PANAMA CITY, FL       ',
#  ('$i94prt', 'PEN'): 'PENSACOLA, FL         ',
#  ('$i94prt', 'PCF'): 'PORT CANAVERAL, FL    ',
#  ('$i94prt', 'PEV'): 'PORT EVERGLADES, FL   ',
#  ('$i94prt', 'PSJ'): 'PORT ST JOE, FL       ',
#  ('$i94prt', 'SFB'): 'SANFORD, FL           ',
#  ('$i94prt', 'SGJ'): 'ST AUGUSTINE ARPT, FL',
#  ('$i94prt', 'SAU'): 'ST AUGUSTINE, FL      ',
#  ('$i94prt', 'FPR'): 'ST LUCIE COUNTY, FL',
#  ('$i94prt', 'SPE'): 'ST PETERSBURG, FL     ',
#  ('$i94prt', 'TAM'): 'TAMPA, FL             ',
#  ('$i94prt', 'WPB'): 'WEST PALM BEACH, FL   ',
#  ('$i94prt', 'ATL'): 'ATLANTA, GA           ',
#  ('$i94prt', 'BRU'): 'BRUNSWICK, GA         ',
#  ('$i94prt', 'AGS'): 'BUSH FIELD - AUGUSTA, GA',
#  ('$i94prt', 'SAV'): 'SAVANNAH, GA          ',
#  ('$i94prt', 'AGA'): 'AGANA, GU             ',
#  ('$i94prt', 'HHW'): 'HONOLULU, HI          ',
#  ('$i94prt', 'OGG'): 'KAHULUI - MAUI, HI',
#  ('$i94prt', 'KOA'): 'KEAHOLE-KONA, HI      ',
#  ('$i94prt', 'LIH'): 'LIHUE, HI             ',
#  ('$i94prt', 'CID'): 'CEDAR RAPIDS/IOWA CITY, IA',
#  ('$i94prt', 'DSM'): 'DES MOINES, IA',
#  ('$i94prt', 'BOI'): 'AIR TERM. (GOWEN FLD) BOISE, ID',
#  ('$i94prt', 'EPI'): 'EASTPORT, ID          ',
#  ('$i94prt', 'IDA'): 'FANNING FIELD - IDAHO FALLS, ID',
#  ('$i94prt', 'PTL'): 'PORTHILL, ID          ',
#  ('$i94prt', 'SPI'): 'CAPITAL - SPRINGFIELD, IL',
#  ('$i94prt', 'CHI'): 'CHICAGO, IL           ',
#  ('$i94prt', 'DPA'): 'DUPAGE COUNTY, IL',
#  ('$i94prt', 'PIA'): 'GREATER PEORIA, IL',
#  ('$i94prt', 'RFD'): 'GREATER ROCKFORD, IL',
#  ('$i94prt', 'UGN'): 'MEMORIAL - WAUKEGAN, IL',
#  ('$i94prt', 'GAR'): 'GARY, IN              ',
#  ('$i94prt', 'HMM'): 'HAMMOND, IN           ',
#  ('$i94prt', 'INP'): 'INDIANAPOLIS, IN      ',
#  ('$i94prt', 'MRL'): 'MERRILLVILLE, IN      ',
#  ('$i94prt', 'SBN'): 'SOUTH BEND, IN',
#  ('$i94prt', 'ICT'): 'MID-CONTINENT - WITCHITA, KS',
#  ('$i94prt', 'LEX'): 'BLUE GRASS - LEXINGTON, KY',
#  ('$i94prt', 'LOU'): 'LOUISVILLE, KY        ',
#  ('$i94prt', 'BTN'): 'BATON ROUGE, LA       ',
#  ('$i94prt', 'LKC'): 'LAKE CHARLES, LA      ',
#  ('$i94prt', 'LAK'): 'LAKE CHARLES, LA (BPS)',
#  ('$i94prt', 'MLU'): 'MONROE, LA',
#  ('$i94prt', 'MGC'): 'MORGAN CITY, LA       ',
#  ('$i94prt', 'NOL'): 'NEW ORLEANS, LA       ',
#  ('$i94prt', 'BOS'): 'BOSTON, MA            ',
#  ('$i94prt', 'GLO'): 'GLOUCESTER, MA        ',
#  ('$i94prt', 'BED'): 'HANSCOM FIELD - BEDFORD, MA',
#  ('$i94prt', 'LYN'): 'LYNDEN, WA            ',
#  ('$i94prt', 'ADW'): 'ANDREWS AFB, MD',
#  ('$i94prt', 'BAL'): 'BALTIMORE, MD         ',
#  ('$i94prt', 'MKG'): 'MUSKEGON, MD',
#  ('$i94prt', 'PAX'): 'PATUXENT RIVER, MD    ',
#  ('$i94prt', 'BGM'): 'BANGOR, ME            ',
#  ('$i94prt', 'BOO'): 'BOOTHBAY HARBOR, ME   ',
#  ('$i94prt', 'BWM'): 'BRIDGEWATER, ME       ',
#  ('$i94prt', 'BCK'): 'BUCKPORT, ME          ',
#  ('$i94prt', 'CLS'): 'CALAIS, ME   ',
#  ('$i94prt', 'CRB'): 'CARIBOU, ME           ',
#  ('$i94prt', 'COB'): 'COBURN GORE, ME       ',
#  ('$i94prt', 'EST'): 'EASTCOURT, ME         ',
#  ('$i94prt', 'EPT'): 'EASTPORT MUNICIPAL, ME',
#  ('$i94prt', 'EPM'): 'EASTPORT, ME          ',
#  ('$i94prt', 'FOR'): 'FOREST CITY, ME       ',
#  ('$i94prt', 'FTF'): 'FORT FAIRFIELD, ME    ',
#  ('$i94prt', 'FTK'): 'FORT KENT, ME         ',
#  ('$i94prt', 'HML'): 'HAMIIN, ME            ',
#  ('$i94prt', 'HTM'): 'HOULTON, ME           ',
#  ('$i94prt', 'JKM'): 'JACKMAN, ME           ',
#  ('$i94prt', 'KAL'): 'KALISPEL, MT          ',
#  ('$i94prt', 'LIM'): 'LIMESTONE, ME         ',
#  ('$i94prt', 'LUB'): 'LUBEC, ME             ',
#  ('$i94prt', 'MAD'): 'MADAWASKA, ME         ',
#  ('$i94prt', 'POM'): 'PORTLAND, ME          ',
#  ('$i94prt', 'RGM'): 'RANGELEY, ME (BPS)',
#  ('$i94prt', 'SBR'): 'SOUTH BREWER, ME      ',
#  ('$i94prt', 'SRL'): 'ST AURELIE, ME        ',
#  ('$i94prt', 'SPA'): 'ST PAMPILE, ME        ',
#  ('$i94prt', 'VNB'): 'VAN BUREN, ME         ',
#  ('$i94prt', 'VCB'): 'VANCEBORO, ME         ',
#  ('$i94prt', 'AGN'): 'ALGONAC, MI           ',
#  ('$i94prt', 'ALP'): 'ALPENA, MI            ',
#  ('$i94prt', 'BCY'): 'BAY CITY, MI          ',
#  ('$i94prt', 'DET'): 'DETROIT, MI           ',
#  ('$i94prt', 'GRP'): 'GRAND RAPIDS, MI',
#  ('$i94prt', 'GRO'): 'GROSSE ISLE, MI       ',
#  ('$i94prt', 'ISL'): 'ISLE ROYALE, MI       ',
#  ('$i94prt', 'MRC'): 'MARINE CITY, MI       ',
#  ('$i94prt', 'MRY'): 'MARYSVILLE, MI        ',
#  ('$i94prt', 'PTK'): 'OAKLAND COUNTY - PONTIAC, MI',
#  ('$i94prt', 'PHU'): 'PORT HURON, MI        ',
#  ('$i94prt', 'RBT'): 'ROBERTS LANDING, MI   ',
#  ('$i94prt', 'SAG'): 'SAGINAW, MI           ',
#  ('$i94prt', 'SSM'): 'SAULT STE. MARIE, MI  ',
#  ('$i94prt', 'SCL'): 'ST CLAIR, MI          ',
#  ('$i94prt', 'YIP'): 'WILLOW RUN - YPSILANTI, MI',
#  ('$i94prt', 'BAU'): 'BAUDETTE, MN          ',
#  ('$i94prt', 'CAR'): 'CARIBOU MUNICIPAL AIRPORT, MN',
#  ('$i94prt', 'GTF'): 'Collapsed into INT, MN',
#  ('$i94prt', 'INL'): 'Collapsed into INT, MN',
#  ('$i94prt', 'CRA'): 'CRANE LAKE, MN        ',
#  ('$i94prt', 'MIC'): 'CRYSTAL MUNICIPAL AIRPORT, MN',
#  ('$i94prt', 'DUL'): 'DULUTH, MN            ',
#  ('$i94prt', 'ELY'): 'ELY, MN               ',
#  ('$i94prt', 'GPM'): 'GRAND PORTAGE, MN     ',
#  ('$i94prt', 'SVC'): 'GRANT COUNTY - SILVER CITY, MN',
#  ('$i94prt', 'INT'): "INT''L FALLS, MN      ",
#  ('$i94prt', 'LAN'): 'LANCASTER, MN         ',
#  ('$i94prt', 'MSP'): 'MINN./ST PAUL, MN     ',
#  ('$i94prt', 'LIN'): 'NORTHERN SVC CENTER, MN   ',
#  ('$i94prt', 'NOY'): 'NOYES, MN             ',
#  ('$i94prt', 'PIN'): 'PINE CREEK, MN        ',
#  ('$i94prt', '48Y'): 'PINECREEK BORDER ARPT, MN',
#  ('$i94prt', 'RAN'): 'RAINER, MN            ',
#  ('$i94prt', 'RST'): 'ROCHESTER, MN',
#  ('$i94prt', 'ROS'): 'ROSEAU, MN            ',
#  ('$i94prt', 'SPM'): 'ST PAUL, MN           ',
#  ('$i94prt', 'WSB'): 'WARROAD INTL, SPB, MN',
#  ('$i94prt', 'WAR'): 'WARROAD, MN           ',
#  ('$i94prt', 'KAN'): 'KANSAS CITY, MO       ',
#  ('$i94prt', 'SGF'): 'SPRINGFIELD-BRANSON, MO',
#  ('$i94prt', 'STL'): 'ST LOUIS, MO          ',
#  ('$i94prt', 'WHI'): 'WHITETAIL, MT         ',
#  ('$i94prt', 'WHM'): 'WILD HORSE, MT        ',
#  ('$i94prt', 'GPT'): 'BILOXI REGIONAL, MS',
#  ('$i94prt', 'GTR'): 'GOLDEN TRIANGLE LOWNDES CNTY, MS',
#  ('$i94prt', 'GUL'): 'GULFPORT, MS          ',
#  ('$i94prt', 'PAS'): 'PASCAGOULA, MS        ',
#  ('$i94prt', 'JAN'): 'THOMPSON FIELD - JACKSON, MS',
#  ('$i94prt', 'BIL'): 'BILLINGS, MT          ',
#  ('$i94prt', 'BTM'): 'BUTTE, MT             ',
#  ('$i94prt', 'CHF'): 'CHIEF MT, MT          ',
#  ('$i94prt', 'CTB'): 'CUT BANK MUNICIPAL, MT',
#  ('$i94prt', 'CUT'): 'CUT BANK, MT          ',
#  ('$i94prt', 'DLB'): 'DEL BONITA, MT        ',
#  ('$i94prt', 'EUR'): 'EUREKA, MT (BPS)',
#  ('$i94prt', 'BZN'): 'GALLATIN FIELD - BOZEMAN, MT',
#  ('$i94prt', 'FCA'): 'GLACIER NATIONAL PARK, MT',
#  ('$i94prt', 'GGW'): 'GLASGOW, MT           ',
#  ('$i94prt', 'GRE'): 'GREAT FALLS, MT       ',
#  ('$i94prt', 'HVR'): 'HAVRE, MT             ',
#  ('$i94prt', 'HEL'): 'HELENA, MT            ',
#  ('$i94prt', 'LWT'): 'LEWISTON, MT          ',
#  ('$i94prt', 'MGM'): 'MORGAN, MT            ',
#  ('$i94prt', 'OPH'): 'OPHEIM, MT            ',
#  ('$i94prt', 'PIE'): 'PIEGAN, MT            ',
#  ('$i94prt', 'RAY'): 'RAYMOND, MT           ',
#  ('$i94prt', 'ROO'): 'ROOSVILLE, MT         ',
#  ('$i94prt', 'SCO'): 'SCOBEY, MT            ',
#  ('$i94prt', 'SWE'): 'SWEETGTASS, MT        ',
#  ('$i94prt', 'TRL'): 'TRIAL CREEK, MT       ',
#  ('$i94prt', 'TUR'): 'TURNER, MT            ',
#  ('$i94prt', 'WCM'): 'WILLOW CREEK, MT      ',
#  ('$i94prt', 'CLT'): 'CHARLOTTE, NC         ',
#  ('$i94prt', 'FAY'): 'FAYETTEVILLE, NC',
#  ('$i94prt', 'MRH'): 'MOREHEAD CITY, NC     ',
#  ('$i94prt', 'FOP'): 'MORRIS FIELDS AAF, NC',
#  ('$i94prt', 'GSO'): 'PIEDMONT TRIAD INTL AIRPORT, NC',
#  ('$i94prt', 'RDU'): 'RALEIGH/DURHAM, NC    ',
#  ('$i94prt', 'SSC'): 'SHAW AFB - SUMTER, NC',
#  ('$i94prt', 'WIL'): 'WILMINGTON, NC        ',
#  ('$i94prt', 'AMB'): 'AMBROSE, ND           ',
#  ('$i94prt', 'ANT'): 'ANTLER, ND            ',
#  ('$i94prt', 'CRY'): 'CARBURY, ND           ',
#  ('$i94prt', 'DNS'): 'DUNSEITH, ND          ',
#  ('$i94prt', 'FAR'): 'FARGO, ND             ',
#  ('$i94prt', 'FRT'): 'FORTUNA, ND           ',
#  ('$i94prt', 'GRF'): 'GRAND FORKS, ND       ',
#  ('$i94prt', 'HNN'): 'HANNAH, ND            ',
#  ('$i94prt', 'HNS'): 'HANSBORO, ND          ',
#  ('$i94prt', 'MAI'): 'MAIDA, ND             ',
#  ('$i94prt', 'MND'): 'MINOT, ND             ',
#  ('$i94prt', 'NEC'): 'NECHE, ND             ',
#  ('$i94prt', 'NOO'): 'NOONAN, ND            ',
#  ('$i94prt', 'NRG'): 'NORTHGATE, ND         ',
#  ('$i94prt', 'PEM'): 'PEMBINA, ND           ',
#  ('$i94prt', 'SAR'): 'SARLES, ND            ',
#  ('$i94prt', 'SHR'): 'SHERWOOD, ND          ',
#  ('$i94prt', 'SJO'): 'ST JOHN, ND           ',
#  ('$i94prt', 'WAL'): 'WALHALLA, ND          ',
#  ('$i94prt', 'WHO'): 'WESTHOPE, ND          ',
#  ('$i94prt', 'WND'): 'WILLISTON, ND         ',
#  ('$i94prt', 'OMA'): 'OMAHA, NE             ',
#  ('$i94prt', 'LEB'): 'LEBANON, NH           ',
#  ('$i94prt', 'MHT'): 'MANCHESTER, NH',
#  ('$i94prt', 'PNH'): 'PITTSBURG, NH         ',
#  ('$i94prt', 'PSM'): 'PORTSMOUTH, NH        ',
#  ('$i94prt', 'BYO'): 'BAYONNE, NJ           ',
#  ('$i94prt', 'CNJ'): 'CAMDEN, NJ            ',
#  ('$i94prt', 'HOB'): 'HOBOKEN, NJ           ',
#  ('$i94prt', 'JER'): 'JERSEY CITY, NJ       ',
#  ('$i94prt', 'WRI'): 'MC GUIRE AFB - WRIGHTSOWN, NJ',
#  ('$i94prt', 'MMU'): 'MORRISTOWN, NJ',
#  ('$i94prt', 'NEW'): 'NEWARK/TETERBORO, NJ  ',
#  ('$i94prt', 'PER'): 'PERTH AMBOY, NJ       ',
#  ('$i94prt', 'ACY'): 'POMONA FIELD - ATLANTIC CITY, NJ',
#  ('$i94prt', 'ALA'): 'ALAMAGORDO, NM (BPS)',
#  ('$i94prt', 'ABQ'): 'ALBUQUERQUE, NM       ',
#  ('$i94prt', 'ANP'): 'ANTELOPE WELLS, NM    ',
#  ('$i94prt', 'CRL'): 'CARLSBAD, NM          ',
#  ('$i94prt', 'COL'): 'COLUMBUS, NM          ',
#  ('$i94prt', 'CDD'): 'CRANE LAKE - ST. LOUIS CNTY, NM',
#  ('$i94prt', 'DNM'): 'DEMING, NM (BPS)',
#  ('$i94prt', 'LAS'): 'LAS CRUCES, NM        ',
#  ('$i94prt', 'LOB'): 'LORDSBURG, NM (BPS)',
#  ('$i94prt', 'RUI'): 'RUIDOSO, NM',
#  ('$i94prt', 'STR'): 'SANTA TERESA, NM      ',
#  ('$i94prt', 'RNO'): 'CANNON INTL - RENO/TAHOE, NV',
#  ('$i94prt', 'FLX'): 'FALLON MUNICIPAL AIRPORT, NV',
#  ('$i94prt', 'LVG'): 'LAS VEGAS, NV         ',
#  ('$i94prt', 'REN'): 'RENO, NV              ',
#  ('$i94prt', 'ALB'): 'ALBANY, NY            ',
#  ('$i94prt', 'AXB'): 'ALEXANDRIA BAY, NY    ',
#  ('$i94prt', 'BUF'): 'BUFFALO, NY           ',
#  ('$i94prt', 'CNH'): 'CANNON CORNERS, NY',
#  ('$i94prt', 'CAP'): 'CAPE VINCENT, NY      ',
#  ('$i94prt', 'CHM'): 'CHAMPLAIN, NY         ',
#  ('$i94prt', 'CHT'): 'CHATEAUGAY, NY        ',
#  ('$i94prt', 'CLA'): 'CLAYTON, NY           ',
#  ('$i94prt', 'FTC'): 'FORT COVINGTON, NY    ',
#  ('$i94prt', 'LAG'): 'LA GUARDIA, NY        ',
#  ('$i94prt', 'LEW'): 'LEWISTON, NY          ',
#  ('$i94prt', 'MAS'): 'MASSENA, NY           ',
#  ('$i94prt', 'MAG'): 'MCGUIRE AFB, NY       ',
#  ('$i94prt', 'MOO'): 'MOORES, NY            ',
#  ('$i94prt', 'MRR'): 'MORRISTOWN, NY        ',
#  ('$i94prt', 'NYC'): 'NEW YORK, NY          ',
#  ('$i94prt', 'NIA'): 'NIAGARA FALLS, NY     ',
#  ('$i94prt', 'OGD'): 'OGDENSBURG, NY        ',
#  ('$i94prt', 'OSW'): 'OSWEGO, NY            ',
#  ('$i94prt', 'ELM'): 'REGIONAL ARPT - HORSEHEAD, NY',
#  ('$i94prt', 'ROC'): 'ROCHESTER, NY         ',
#  ('$i94prt', 'ROU'): 'ROUSES POINT, NY      ',
#  ('$i94prt', 'SWF'): 'STEWART - ORANGE CNTY, NY',
#  ('$i94prt', 'SYR'): 'SYRACUSE, NY          ',
#  ('$i94prt', 'THO'): 'THOUSAND ISLAND BRIDGE, NY',
#  ('$i94prt', 'TRO'): 'TROUT RIVER, NY       ',
#  ('$i94prt', 'WAT'): 'WATERTOWN, NY         ',
#  ('$i94prt', 'HPN'): 'WESTCHESTER - WHITE PLAINS, NY',
#  ('$i94prt', 'WRB'): 'WHIRLPOOL BRIDGE, NY',
#  ('$i94prt', 'YOU'): 'YOUNGSTOWN, NY        ',
#  ('$i94prt', 'AKR'): 'AKRON, OH             ',
#  ('$i94prt', 'ATB'): 'ASHTABULA, OH         ',
#  ('$i94prt', 'CIN'): 'CINCINNATI, OH        ',
#  ('$i94prt', 'CLE'): 'CLEVELAND, OH         ',
#  ('$i94prt', 'CLM'): 'COLUMBUS, OH          ',
#  ('$i94prt', 'LOR'): 'LORAIN, OH            ',
#  ('$i94prt', 'MBO'): 'MARBLE HEADS, OH      ',
#  ('$i94prt', 'SDY'): 'SANDUSKY, OH          ',
#  ('$i94prt', 'TOL'): 'TOLEDO, OH            ',
#  ('$i94prt', 'OKC'): 'OKLAHOMA CITY, OK     ',
#  ('$i94prt', 'TUL'): 'TULSA, OK',
#  ('$i94prt', 'AST'): 'ASTORIA, OR           ',
#  ('$i94prt', 'COO'): 'COOS BAY, OR          ',
#  ('$i94prt', 'HIO'): 'HILLSBORO, OR',
#  ('$i94prt', 'MED'): 'MEDFORD, OR           ',
#  ('$i94prt', 'NPT'): 'NEWPORT, OR           ',
#  ('$i94prt', 'POO'): 'PORTLAND, OR          ',
#  ('$i94prt', 'PUT'): 'PUT-IN-BAY, OH        ',
#  ('$i94prt', 'RDM'): 'ROBERTS FIELDS - REDMOND, OR',
#  ('$i94prt', 'ERI'): 'ERIE, PA              ',
#  ('$i94prt', 'MDT'): 'HARRISBURG, PA',
#  ('$i94prt', 'HSB'): 'HARRISONBURG, PA      ',
#  ('$i94prt', 'PHI'): 'PHILADELPHIA, PA      ',
#  ('$i94prt', 'PIT'): 'PITTSBURG, PA         ',
#  ('$i94prt', 'AGU'): 'AGUADILLA, PR         ',
#  ('$i94prt', 'BQN'): 'BORINQUEN - AGUADILLO, PR',
#  ('$i94prt', 'JCP'): 'CULEBRA - BENJAMIN RIVERA, PR',
#  ('$i94prt', 'ENS'): 'ENSENADA, PR          ',
#  ('$i94prt', 'FAJ'): 'FAJARDO, PR           ',
#  ('$i94prt', 'HUM'): 'HUMACAO, PR           ',
#  ('$i94prt', 'JOB'): 'JOBOS, PR             ',
#  ('$i94prt', 'MAY'): 'MAYAGUEZ, PR          ',
#  ('$i94prt', 'PON'): 'PONCE, PR             ',
#  ('$i94prt', 'PSE'): 'PONCE-MERCEDITA, PR',
#  ('$i94prt', 'SAJ'): 'SAN JUAN, PR          ',
#  ('$i94prt', 'VQS'): 'VIEQUES-ARPT, PR',
#  ('$i94prt', 'PRO'): 'PROVIDENCE, RI        ',
#  ('$i94prt', 'PVD'): 'THEODORE FRANCIS - WARWICK, RI',
#  ('$i94prt', 'CHL'): 'CHARLESTON, SC        ',
#  ('$i94prt', 'CAE'): 'COLUMBIA, SC #ARPT',
#  ('$i94prt', 'GEO'): 'GEORGETOWN, SC        ',
#  ('$i94prt', 'GSP'): 'GREENVILLE, SC',
#  ('$i94prt', 'GRR'): 'GREER, SC',
#  ('$i94prt', 'MYR'): 'MYRTLE BEACH, SC',
#  ('$i94prt', 'SPF'): 'BLACK HILLS, SPEARFISH, SD',
#  ('$i94prt', 'HON'): 'HOWES REGIONAL ARPT - HURON, SD',
#  ('$i94prt', 'SAI'): 'SAIPAN, SPN           ',
#  ('$i94prt', 'TYS'): 'MC GHEE TYSON - ALCOA, TN',
#  ('$i94prt', 'MEM'): 'MEMPHIS, TN           ',
#  ('$i94prt', 'NSV'): 'NASHVILLE, TN         ',
#  ('$i94prt', 'TRI'): 'TRI CITY ARPT, TN',
#  ('$i94prt', 'ADS'): 'ADDISON AIRPORT- ADDISON, TX',
#  ('$i94prt', 'ADT'): 'AMISTAD DAM, TX       ',
#  ('$i94prt', 'ANZ'): 'ANZALDUAS, TX',
#  ('$i94prt', 'AUS'): 'AUSTIN, TX            ',
#  ('$i94prt', 'BEA'): 'BEAUMONT, TX          ',
#  ('$i94prt', 'BBP'): 'BIG BEND PARK, TX (BPS)',
#  ('$i94prt', 'SCC'): 'BP SPEC COORD. CTR, TX',
#  ('$i94prt', 'BTC'): 'BP TACTICAL UNIT, TX  ',
#  ('$i94prt', 'BOA'): 'BRIDGE OF AMERICAS, TX',
#  ('$i94prt', 'BRO'): 'BROWNSVILLE, TX       ',
#  ('$i94prt', 'CRP'): 'CORPUS CHRISTI, TX    ',
#  ('$i94prt', 'DAL'): 'DALLAS, TX            ',
#  ('$i94prt', 'DLR'): 'DEL RIO, TX           ',
#  ('$i94prt', 'DNA'): 'DONNA, TX',
#  ('$i94prt', 'EGP'): 'EAGLE PASS, TX        ',
#  ('$i94prt', 'ELP'): 'EL PASO, TX           ',
#  ('$i94prt', 'FAB'): 'FABENS, TX            ',
#  ('$i94prt', 'FAL'): 'FALCON HEIGHTS, TX    ',
#  ('$i94prt', 'FTH'): 'FORT HANCOCK, TX      ',
#  ('$i94prt', 'AFW'): 'FORT WORTH ALLIANCE, TX',
#  ('$i94prt', 'FPT'): 'FREEPORT, TX          ',
#  ('$i94prt', 'GAL'): 'GALVESTON, TX         ',
#  ('$i94prt', 'HLG'): 'HARLINGEN, TX         ',
#  ('$i94prt', 'HID'): 'HIDALGO, TX           ',
#  ('$i94prt', 'HOU'): 'HOUSTON, TX           ',
#  ('$i94prt', 'SGR'): 'HULL FIELD, SUGAR LAND ARPT, TX',
#  ('$i94prt', 'LLB'): 'JUAREZ-LINCOLN BRIDGE, TX',
#  ('$i94prt', 'LCB'): 'LAREDO COLUMBIA BRIDGE, TX',
#  ('$i94prt', 'LRN'): 'LAREDO NORTH, TX      ',
#  ('$i94prt', 'LAR'): 'LAREDO, TX            ',
#  ('$i94prt', 'LSE'): 'LOS EBANOS, TX        ',
#  ('$i94prt', 'IND'): 'LOS INDIOS, TX',
#  ('$i94prt', 'LOI'): 'LOS INDIOS, TX        ',
#  ('$i94prt', 'MRS'): 'MARFA, TX (BPS)',
#  ('$i94prt', 'MCA'): 'MCALLEN, TX           ',
#  ('$i94prt', 'MAF'): 'ODESSA REGIONAL, TX',
#  ('$i94prt', 'PDN'): 'PASO DEL NORTE,TX     ',
#  ('$i94prt', 'PBB'): 'PEACE BRIDGE, NY      ',
#  ('$i94prt', 'PHR'): 'PHARR, TX             ',
#  ('$i94prt', 'PAR'): 'PORT ARTHUR, TX       ',
#  ('$i94prt', 'ISB'): 'PORT ISABEL, TX       ',
#  ('$i94prt', 'POE'): 'PORT OF EL PASO, TX   ',
#  ('$i94prt', 'PRE'): 'PRESIDIO, TX          ',
#  ('$i94prt', 'PGR'): 'PROGRESO, TX          ',
#  ('$i94prt', 'RIO'): 'RIO GRANDE CITY, TX   ',
#  ('$i94prt', 'ROM'): 'ROMA, TX              ',
#  ('$i94prt', 'SNA'): 'SAN ANTONIO, TX       ',
#  ('$i94prt', 'SNN'): 'SANDERSON, TX         ',
#  ('$i94prt', 'VIB'): 'VETERAN INTL BRIDGE, TX',
#  ('$i94prt', 'YSL'): 'YSLETA, TX            ',
#  ('$i94prt', 'CHA'): 'CHARLOTTE AMALIE, VI  ',
#  ('$i94prt', 'CHR'): 'CHRISTIANSTED, VI     ',
#  ('$i94prt', 'CRU'): 'CRUZ BAY, ST JOHN, VI ',
#  ('$i94prt', 'FRK'): 'FREDERIKSTED, VI      ',
#  ('$i94prt', 'STT'): 'ST THOMAS, VI         ',
#  ('$i94prt', 'LGU'): 'CACHE AIRPORT - LOGAN, UT',
#  ('$i94prt', 'SLC'): 'SALT LAKE CITY, UT    ',
#  ('$i94prt', 'CHO'): 'ALBEMARLE CHARLOTTESVILLE, VA',
#  ('$i94prt', 'DAA'): 'DAVISON AAF - FAIRFAX CNTY, VA',
#  ('$i94prt', 'HOP'): 'HOPEWELL, VA          ',
#  ('$i94prt', 'HEF'): 'MANASSAS, VA #ARPT',
#  ('$i94prt', 'NWN'): 'NEWPORT, VA           ',
#  ('$i94prt', 'NOR'): 'NORFOLK, VA           ',
#  ('$i94prt', 'RCM'): 'RICHMOND, VA          ',
#  ('$i94prt', 'ABS'): 'ALBURG SPRINGS, VT    ',
#  ('$i94prt', 'ABG'): 'ALBURG, VT            ',
#  ('$i94prt', 'BEB'): 'BEEBE PLAIN, VT       ',
#  ('$i94prt', 'BEE'): 'BEECHER FALLS, VT     ',
#  ('$i94prt', 'BRG'): 'BURLINGTON, VT        ',
#  ('$i94prt', 'CNA'): 'CANAAN, VT            ',
#  ('$i94prt', 'DER'): 'DERBY LINE, VT (I-91) ',
#  ('$i94prt', 'DLV'): 'DERBY LINE, VT (RT. 5)',
#  ('$i94prt', 'ERC'): 'EAST RICHFORD, VT     ',
#  ('$i94prt', 'HIG'): 'HIGHGATE SPRINGS, VT  ',
#  ('$i94prt', 'MOR'): 'MORSES LINE, VT       ',
#  ('$i94prt', 'NPV'): 'NEWPORT, VT           ',
#  ('$i94prt', 'NRT'): 'NORTH TROY, VT        ',
#  ('$i94prt', 'NRN'): 'NORTON, VT            ',
#  ('$i94prt', 'PIV'): 'PINNACLE ROAD, VT     ',
#  ('$i94prt', 'RIF'): 'RICHFORT, VT          ',
#  ('$i94prt', 'STA'): 'ST ALBANS, VT         ',
#  ('$i94prt', 'SWB'): 'SWANTON, VT (BP - SECTOR HQ)',
#  ('$i94prt', 'WBE'): 'WEST BERKSHIRE, VT    ',
#  ('$i94prt', 'ABE'): 'ABERDEEN, WA          ',
#  ('$i94prt', 'ANA'): 'ANACORTES, WA         ',
#  ('$i94prt', 'BEL'): 'BELLINGHAM, WA        ',
#  ('$i94prt', 'BLI'): 'BELLINGHAM, WASHINGTON #INTL',
#  ('$i94prt', 'BLA'): 'BLAINE, WA            ',
#  ('$i94prt', 'BWA'): 'BOUNDARY, WA          ',
#  ('$i94prt', 'CUR'): 'CURLEW, WA (BPS)',
#  ('$i94prt', 'DVL'): 'DANVILLE, WA          ',
#  ('$i94prt', 'EVE'): 'EVERETT, WA           ',
#  ('$i94prt', 'FER'): 'FERRY, WA             ',
#  ('$i94prt', 'FRI'): 'FRIDAY HARBOR, WA     ',
#  ('$i94prt', 'FWA'): 'FRONTIER, WA          ',
#  ('$i94prt', 'KLM'): 'KALAMA, WA            ',
#  ('$i94prt', 'LAU'): 'LAURIER, WA           ',
#  ('$i94prt', 'LON'): 'LONGVIEW, WA          ',
#  ('$i94prt', 'MET'): 'METALINE FALLS, WA    ',
#  ('$i94prt', 'MWH'): 'MOSES LAKE GRANT COUNTY ARPT, WA',
#  ('$i94prt', 'NEA'): 'NEAH BAY, WA          ',
#  ('$i94prt', 'NIG'): 'NIGHTHAWK, WA         ',
#  ('$i94prt', 'OLY'): 'OLYMPIA, WA           ',
#  ('$i94prt', 'ORO'): 'OROVILLE, WA          ',
#  ('$i94prt', 'PWB'): 'PASCO, WA             ',
#  ('$i94prt', 'PIR'): 'POINT ROBERTS, WA     ',
#  ('$i94prt', 'PNG'): 'PORT ANGELES, WA      ',
#  ('$i94prt', 'PTO'): 'PORT TOWNSEND, WA     ',
#  ('$i94prt', 'SEA'): 'SEATTLE, WA           ',
#  ('$i94prt', 'SPO'): 'SPOKANE, WA           ',
#  ('$i94prt', 'SUM'): 'SUMAS, WA             ',
#  ('$i94prt', 'TAC'): 'TACOMA, WA            ',
#  ('$i94prt', 'PSC'): 'TRI-CITIES - PASCO, WA',
#  ('$i94prt', 'VAN'): 'VANCOUVER, WA         ',
#  ('$i94prt', 'AGM'): 'ALGOMA, WI            ',
#  ('$i94prt', 'BAY'): 'BAYFIELD, WI          ',
#  ('$i94prt', 'GRB'): 'GREEN BAY, WI         ',
#  ('$i94prt', 'MNW'): 'MANITOWOC, WI         ',
#  ('$i94prt', 'MIL'): 'MILWAUKEE, WI         ',
#  ('$i94prt', 'MSN'): 'TRUAX FIELD - DANE COUNTY, WI',
#  ('$i94prt', 'CHS'): 'CHARLESTON, WV        ',
#  ('$i94prt', 'CLK'): 'CLARKSBURG, WV        ',
#  ('$i94prt', 'BLF'): 'MERCER COUNTY, WV',
#  ('$i94prt', 'CSP'): 'CASPER, WY            ',
#  ('$i94prt', 'XXX'): 'NOT REPORTED/UNKNOWN  ',
#  ('$i94prt', '888'): 'UNIDENTIFED AIR / SEAPORT',
#  ('$i94prt', 'UNK'): 'UNKNOWN POE           ',
#  ('$i94prt', 'CLG'): 'CALGARY, CANADA       ',
#  ('$i94prt', 'EDA'): 'EDMONTON, CANADA      ',
#  ('$i94prt', 'YHC'): 'HAKAI PASS, CANADA',
#  ('$i94prt', 'HAL'): 'Halifax, NS, Canada   ',
#  ('$i94prt', 'MON'): 'MONTREAL, CANADA      ',
#  ('$i94prt', 'OTT'): 'OTTAWA, CANADA        ',
#  ('$i94prt', 'YXE'): 'SASKATOON, CANADA',
#  ('$i94prt', 'TOR'): 'TORONTO, CANADA       ',
#  ('$i94prt', 'VCV'): 'VANCOUVER, CANADA     ',
#  ('$i94prt', 'VIC'): 'VICTORIA, CANADA      ',
#  ('$i94prt', 'WIN'): 'WINNIPEG, CANADA      ',
#  ('$i94prt', 'AMS'): 'AMSTERDAM-SCHIPHOL, NETHERLANDS',
#  ('$i94prt', 'ARB'): 'ARUBA, NETH ANTILLES  ',
#  ('$i94prt', 'BAN'): 'BANKOK, THAILAND      ',
#  ('$i94prt', 'BEI'): 'BEICA #ARPT, ETHIOPIA',
#  ('$i94prt', 'PEK'): 'BEIJING CAPITAL INTL, PRC',
#  ('$i94prt', 'BDA'): 'KINDLEY FIELD, BERMUDA',
#  ('$i94prt', 'BOG'): 'BOGOTA, EL DORADO #ARPT, COLOMBIA',
#  ('$i94prt', 'EZE'): 'BUENOS AIRES, MINISTRO PIST, ARGENTINA',
#  ('$i94prt', 'CUN'): 'CANCUN, MEXICO',
#  ('$i94prt', 'CRQ'): 'CARAVELAS, BA #ARPT, BRAZIL',
#  ('$i94prt', 'MVD'): 'CARRASCO, URUGUAY',
#  ('$i94prt', 'DUB'): 'DUBLIN, IRELAND       ',
#  ('$i94prt', 'FOU'): 'FOUGAMOU #ARPT, GABON',
#  ('$i94prt', 'FBA'): 'FREEPORT, BAHAMAS      ',
#  ('$i94prt', 'MTY'): 'GEN M. ESCOBEDO, Monterrey, MX',
#  ('$i94prt', 'HMO'): 'GEN PESQUEIRA GARCIA, MX',
#  ('$i94prt', 'GCM'): 'GRAND CAYMAN, CAYMAN ISLAND',
#  ('$i94prt', 'GDL'): 'GUADALAJARA, MIGUEL HIDAL, MX',
#  ('$i94prt', 'HAM'): 'HAMILTON, BERMUDA     ',
#  ('$i94prt', 'ICN'): 'INCHON, SEOUL KOREA',
#  ('$i94prt', 'IWA'): 'INVALID - IWAKUNI, JAPAN',
#  ('$i94prt', 'CND'): 'KOGALNICEANU, ROMANIA',
#  ('$i94prt', 'LAH'): 'LABUHA ARPT, INDONESIA',
#  ('$i94prt', 'DUR'): 'LOUIS BOTHA, SOUTH AFRICA',
#  ('$i94prt', 'MAL'): 'MANGOLE ARPT, INDONESIA',
#  ('$i94prt', 'MDE'): 'MEDELLIN, COLOMBIA',
#  ('$i94prt', 'MEX'): 'JUAREZ INTL, MEXICO CITY, MX',
#  ('$i94prt', 'LHR'): 'MIDDLESEX, ENGLAND',
#  ('$i94prt', 'NBO'): 'NAIROBI, KENYA        ',
#  ('$i94prt', 'NAS'): 'NASSAU, BAHAMAS       ',
#  ('$i94prt', 'NCA'): 'NORTH CAICOS, TURK & CAIMAN',
#  ('$i94prt', 'PTY'): 'OMAR TORRIJOS, PANAMA',
#  ('$i94prt', 'SPV'): 'PAPUA, NEW GUINEA',
#  ('$i94prt', 'UIO'): 'QUITO (MARISCAL SUCR), ECUADOR',
#  ('$i94prt', 'RIT'): 'ROME, ITALY           ',
#  ('$i94prt', 'SNO'): 'SAKON NAKHON #ARPT, THAILAND',
#  ('$i94prt', 'SLP'): 'SAN LUIS POTOSI #ARPT, MEXICO',
#  ('$i94prt', 'SAN'): 'SAN SALVADOR, EL SALVADOR',
#  ('$i94prt', 'SRO'): 'SANTANA RAMOS #ARPT, COLOMBIA',
#  ('$i94prt', 'GRU'): 'GUARULHOS INTL, SAO PAULO, BRAZIL',
#  ('$i94prt', 'SHA'): 'SHANNON, IRELAND      ',
#  ('$i94prt', 'HIL'): 'SHILLAVO, ETHIOPIA',
#  ('$i94prt', 'TOK'): 'TOROKINA #ARPT, PAPUA, NEW GUINEA',
#  ('$i94prt', 'VER'): 'VERACRUZ, MEXICO',
#  ('$i94prt', 'LGW'): 'WEST SUSSEX, ENGLAND  ',
#  ('$i94prt', 'ZZZ'): 'MEXICO Land (Banco de Mexico) ',
#  ('$i94prt', 'CHN'): 'No PORT Code (CHN)',
#  ('$i94prt', 'CNC'): 'CANNON CORNERS, NY',
#  ('$i94prt', 'MAA'): 'Abu Dhabi',
#  ('$i94prt', 'AG0'): 'MAGNOLIA, AR',
#  ('$i94prt', 'BHM'): 'BAR HARBOR, ME',
#  ('$i94prt', 'BHX'): 'BIRMINGHAM, AL',
#  ('$i94prt', 'CAK'): 'AKRON, OH',
#  ('$i94prt', 'FOK'): 'SUFFOLK COUNTY, NY',
#  ('$i94prt', 'LND'): 'LANDER, WY',
#  ('$i94prt', 'MAR'): 'MARFA, TX',
#  ('$i94prt', 'MLI'): 'MOLINE, IL',
#  ('$i94prt', 'RIV'): 'RIVERSIDE, CA',
#  ('$i94prt', 'RME'): 'ROME, NY',
#  ('$i94prt', 'VNY'): 'VAN NUYS, CA',
#  ('$i94prt', 'YUM'): 'YUMA, AZ',
#  ('$i94prt', 'FRG'): 'Collapsed (FOK) 06/15',
#  ('$i94prt', 'HRL'): 'Collapsed (HLG) 06/15',
#  ('$i94prt', 'ISP'): 'Collapsed (FOK) 06/15',
#  ('$i94prt', 'JSJ'): 'Collapsed (SAJ) 06/15',
#  ('$i94prt', 'BUS'): 'Collapsed (BUF) 06/15',
#  ('$i94prt', 'IAG'): 'Collapsed (NIA) 06/15',
#  ('$i94prt', 'PHN'): 'Collapsed (PHU) 06/15',
#  ('$i94prt', 'STN'): 'Collapsed (STR) 06/15',
#  ('$i94prt', 'VMB'): 'Collapsed (VNB) 06/15',
#  ('$i94prt', 'T01'): 'Collapsed (SEA) 06/15',
#  ('$i94prt', 'PHF'): 'No PORT Code (PHF)',
#  ('$i94prt', 'DRV'): 'No PORT Code (DRV)',
#  ('$i94prt', 'FTB'): 'No PORT Code (FTB)',
#  ('$i94prt', 'GAC'): 'No PORT Code (GAC)',
#  ('$i94prt', 'GMT'): 'No PORT Code (GMT)',
#  ('$i94prt', 'JFA'): 'No PORT Code (JFA)',
#  ('$i94prt', 'JMZ'): 'No PORT Code (JMZ)',
#  ('$i94prt', 'NC8'): 'No PORT Code (NC8)',
#  ('$i94prt', 'NYL'): 'No PORT Code (NYL)',
#  ('$i94prt', 'OAI'): 'No PORT Code (OAI)',
#  ('$i94prt', 'PCW'): 'No PORT Code (PCW)',
#  ('$i94prt', 'WA5'): 'No PORT Code (WAS)',
#  ('$i94prt', 'WTR'): 'No PORT Code (WTR)',
#  ('$i94prt', 'X96'): 'No PORT Code (X96)',
#  ('$i94prt', 'XNA'): 'No PORT Code (XNA)',
#  ('$i94prt', 'YGF'): 'No PORT Code (YGF)',
#  ('$i94prt', '5T6'): 'No PORT Code (5T6)',
#  ('$i94prt', '060'): 'No PORT Code (60)',
#  ('$i94prt', 'SP0'): 'No PORT Code (SP0)',
#  ('$i94prt', 'W55'): 'No PORT Code (W55)',
#  ('$i94prt', 'X44'): 'No PORT Code (X44)',
#  ('$i94prt', 'AUH'): 'No PORT Code (AUH)',
#  ('$i94prt', 'RYY'): 'No PORT Code (RYY)',
#  ('$i94prt', 'SUS'): 'No PORT Code (SUS)',
#  ('$i94prt', '74S'): 'No PORT Code (74S)',
#  ('$i94prt', 'ATW'): 'No PORT Code (ATW)',
#  ('$i94prt', 'CPX'): 'No PORT Code (CPX)',
#  ('$i94prt', 'MTH'): 'No PORT Code (MTH)',
#  ('$i94prt', 'PFN'): 'No PORT Code (PFN)',
#  ('$i94prt', 'SCH'): 'No PORT Code (SCH)',
#  ('$i94prt', 'ASI'): 'No PORT Code (ASI)',
#  ('$i94prt', 'BKF'): 'No PORT Code (BKF)',
#  ('$i94prt', 'DAY'): 'No PORT Code (DAY)',
#  ('$i94prt', 'Y62'): 'No PORT Code (Y62)',
#  ('$i94prt', 'AG'): 'No PORT Code (AG)',
#  ('$i94prt', 'BCM'): 'No PORT Code (BCM)',
#  ('$i94prt', 'DEC'): 'No PORT Code (DEC)',
#  ('$i94prt', 'PLB'): 'No PORT Code (PLB)',
#  ('$i94prt', 'CXO'): 'No PORT Code (CXO)',
#  ('$i94prt', 'JBQ'): 'No PORT Code (JBQ)',
#  ('$i94prt', 'JIG'): 'No PORT Code (JIG)',
#  ('$i94prt', 'OGS'): 'No PORT Code (OGS)',
#  ('$i94prt', 'TIW'): 'No PORT Code (TIW)',
#  ('$i94prt', 'OTS'): 'No PORT Code (OTS)',
#  ('$i94prt', 'AMT'): 'No PORT Code (AMT)',
#  ('$i94prt', 'EGE'): 'No PORT Code (EGE)',
#  ('$i94prt', 'GPI'): 'No PORT Code (GPI)',
#  ('$i94prt', 'NGL'): 'No PORT Code (NGL)',
#  ('$i94prt', 'OLM'): 'No PORT Code (OLM)',
#  ('$i94prt', '.GA'): 'No PORT Code (.GA)',
#  ('$i94prt', 'CLX'): 'No PORT Code (CLX)',
#  ('$i94prt', 'CP '): 'No PORT Code (CP)',
#  ('$i94prt', 'FSC'): 'No PORT Code (FSC)',
#  ('$i94prt', 'NK'): 'No PORT Code (NK)',
#  ('$i94prt', 'ADU'): 'No PORT Code (ADU)',
#  ('$i94prt', 'AKT'): 'No PORT Code (AKT)',
#  ('$i94prt', 'LIT'): 'No PORT Code (LIT)',
#  ('$i94prt', 'A2A'): 'No PORT Code (A2A)',
#  ('$i94prt', 'OSN'): 'No PORT Code (OSN)',
#  'arrdate': 'is the Arrival Date in the USA. It is a SAS date numeric field that ais the Arrival Date in the USA. It is a SAS date numeric field that ais the Arrival Date in the USA. It is a SAS date numeric field that a',
#  'i94mode': 'There are missing values as well as not reported (9)',
#  ('i94mode', '1'): 'Air',
#  ('i94mode', '2'): 'Sea',
#  ('i94mode', '3'): 'Land',
#  ('i94mode', '9'): "Not reported' ;",
#  'i94addr': 'There is lots of invalid codes in this variable and the list belowThere is lots of invalid codes in this variable and the list below',
#  ('i94addr', 'AL'): 'ALABAMA',
#  ('i94addr', 'AK'): 'ALASKA',
#  ('i94addr', 'AZ'): 'ARIZONA',
#  ('i94addr', 'AR'): 'ARKANSAS',
#  ('i94addr', 'CA'): 'CALIFORNIA',
#  ('i94addr', 'CO'): 'COLORADO',
#  ('i94addr', 'CT'): 'CONNECTICUT',
#  ('i94addr', 'DE'): 'DELAWARE',
#  ('i94addr', 'DC'): 'DIST. OF COLUMBIA',
#  ('i94addr', 'FL'): 'FLORIDA',
#  ('i94addr', 'GA'): 'GEORGIA',
#  ('i94addr', 'GU'): 'GUAM',
#  ('i94addr', 'HI'): 'HAWAII',
#  ('i94addr', 'ID'): 'IDAHO',
#  ('i94addr', 'IL'): 'ILLINOIS',
#  ('i94addr', 'IN'): 'INDIANA',
#  ('i94addr', 'IA'): 'IOWA',
#  ('i94addr', 'KS'): 'KANSAS',
#  ('i94addr', 'KY'): 'KENTUCKY',
#  ('i94addr', 'LA'): 'LOUISIANA',
#  ('i94addr', 'ME'): 'MAINE',
#  ('i94addr', 'MD'): 'MARYLAND',
#  ('i94addr', 'MA'): 'MASSACHUSETTS',
#  ('i94addr', 'MI'): 'MICHIGAN',
#  ('i94addr', 'MN'): 'MINNESOTA',
#  ('i94addr', 'MS'): 'MISSISSIPPI',
#  ('i94addr', 'MO'): 'MISSOURI',
#  ('i94addr', 'MT'): 'MONTANA',
#  ('i94addr', 'NC'): 'N. CAROLINA',
#  ('i94addr', 'ND'): 'N. DAKOTA',
#  ('i94addr', 'NE'): 'NEBRASKA',
#  ('i94addr', 'NV'): 'NEVADA',
#  ('i94addr', 'NH'): 'NEW HAMPSHIRE',
#  ('i94addr', 'NJ'): 'NEW JERSEY',
#  ('i94addr', 'NM'): 'NEW MEXICO',
#  ('i94addr', 'NY'): 'NEW YORK',
#  ('i94addr', 'OH'): 'OHIO',
#  ('i94addr', 'OK'): 'OKLAHOMA',
#  ('i94addr', 'OR'): 'OREGON',
#  ...}
